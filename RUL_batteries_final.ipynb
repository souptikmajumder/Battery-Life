# %% [markdown]
# <a href="https://colab.research.google.com/github/souptikmajumder/Battery-Life/blob/main/RUL_batteries_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)

# %%
#importing all the required libraries
from scipy.io import loadmat
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Considering the available data of Charge/Discharge and Impedance measurement at 25 degree C only.

# %%
#*************************loading the data for 25 degree********************************
#5 cycle hppc discharge test
data_25_deg_5_hppc = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/5 pulse disch/03-11-17_08.47 25degC_5Pulse_HPPC_Pan18650PF.mat")

data_25_deg_dis_5_10 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/5 pulse disch/03-11-17_10.10 3390_dis5_10p.mat")
#charges and pauses
data_25_deg_1 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-11-17_08.25 3390_TS003014.mat")
data_25_deg_2 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-12-17_11.58 3390_Charge_2.mat")
data_25_deg_3 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-18-17_00.05 3406_Charge1.mat")
data_25_deg_4 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-18-17_00.23 3406_Pause1.mat")
data_25_deg_5 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_02.26 3406_Pause2.mat")
data_25_deg_6 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_06.31 3406_Charge2.mat")
data_25_deg_7 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_08.08 3406_Pause3.mat")
data_25_deg_8 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_11.59 3406_Charge3.mat")
data_25_deg_9 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_13.32 3406_Pause4.mat")
data_25_deg_10 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-19-17_17.53 3406_Charge4.mat")
data_25_deg_11 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_00.44 3415_Pause1.mat")
data_25_deg_12 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_03.05 3415_Charge1.mat")
data_25_deg_13 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_04.57 3415_Pause2.mat")
data_25_deg_14 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_08.04 3415_Charge2.mat")
data_25_deg_15 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_18.28 3416_Pause2.mat")
data_25_deg_16 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_21.35 3416_Charge2.mat")
data_25_deg_17 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-20-17_23.30 3416_Pause3.mat")
data_25_deg_18 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-21-17_06.44 3416_Charge3.mat")
data_25_deg_19 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-21-17_08.39 3416_Pause4.mat")
data_25_deg_20 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-21-17_13.34 3416_Charge4.mat")
data_25_deg_21 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-21-17_15.28 3416_Pause5.mat")
data_25_deg_22 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/03-21-17_19.43 3416_Charge5.mat")
data_25_deg_23 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/04-27-17_08.52 3541_Charge1a.mat")
data_25_deg_24 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/04-27-17_11.53 3541_dis5_10p.mat")
data_25_deg_25 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Charges and Pauses/04-29-17_13.07 3541_Charge2a.mat")

#drive cycles
data_25_deg_drive_cycle_1 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-18-17_02.17 25degC_Cycle_1_Pan18650PF.mat")
data_25_deg_drive_cycle_2 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-19-17_03.25 25degC_Cycle_2_Pan18650PF.mat")
data_25_deg_drive_cycle_3 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-19-17_09.07 25degC_Cycle_3_Pan18650PF.mat")
data_25_deg_drive_cycle_4 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-19-17_14.31 25degC_Cycle_4_Pan18650PF.mat")
data_25_deg_drive_cycle_US06 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-20-17_01.43 25degC_US06_Pan18650PF.mat")
data_25_deg_drive_cycle_HWFT_a = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-20-17_05.56 25degC_HWFTa_Pan18650PF.mat")
data_25_deg_drive_cycle_HWFT_b = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-20-17_19.27 25degC_HWFTb_Pan18650PF.mat")
data_25_deg_drive_cycle_UDDS = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-21-17_00.29 25degC_UDDS_Pan18650PF.mat")
data_25_deg_drive_cycle_LA92 = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-21-17_09.38 25degC_LA92_Pan18650PF.mat")
data_25_deg_drive_cycle_NN = loadmat(r"/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/Drive cycles/03-21-17_16.27 25degC_NN_Pan18650PF.mat")

# %%
#create a list of all the 25 charging and discharging profiles at 25 degree
deg_25_list = [data_25_deg_1,data_25_deg_2,data_25_deg_3,data_25_deg_4,data_25_deg_5,data_25_deg_6,
              data_25_deg_7,data_25_deg_8,data_25_deg_9,data_25_deg_10,data_25_deg_11,data_25_deg_12,
              data_25_deg_13,data_25_deg_14,data_25_deg_15,data_25_deg_16,data_25_deg_17,data_25_deg_18,
              data_25_deg_19,data_25_deg_20,data_25_deg_21,data_25_deg_22,data_25_deg_23,data_25_deg_24,
              data_25_deg_25]

#create a list of all the 9 drive cycles at 25 degree
deg_25_drives = [data_25_deg_drive_cycle_1,data_25_deg_drive_cycle_2,data_25_deg_drive_cycle_3,data_25_deg_drive_cycle_4]

# %%
#TimeStamp,Voltage,Current,Ah,Wh,Power,Battery_Temp_degC,Time,Chamber_Temp_degC = ([],)*9
TimeStamp=[];Voltage = [];Current = [];Ah = [];Wh=[];Power=[];Battery_Temp_degC=[];
Time=[];Chamber_Temp_degC=[];

TimeStamp_f,Voltage_f,Current_f,Ah_f,Wh_f,Power_f,Battery_Temp_degC_f,Time_f,Chamber_Temp_degC_f = ([],)*9

from itertools import chain

for i in range(0,25):
    TimeStamp.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][0])))
    Voltage.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][1])))
    Current.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][2])))  
    Ah.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][3])))        
    Wh.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][4])))
    Power.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][5])))
    Battery_Temp_degC.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][6])))
    Time.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][7])))
    Chamber_Temp_degC.append(list(chain.from_iterable(deg_25_list[i]['meas'][0][0][8])))


#unzipping all the list elements in the final lists to form dataframe
TimeStamp_f= list(chain.from_iterable(TimeStamp))
Voltage_f = list(chain.from_iterable(Voltage))
Current_f = list(chain.from_iterable(Current))
Ah_f = list(chain.from_iterable(Ah))
Wh_f = list(chain.from_iterable(Wh))
Power_f = list(chain.from_iterable(Power))
Battery_Temp_degC_f = list(chain.from_iterable(Battery_Temp_degC))
Time_f = list(chain.from_iterable(Time))
Chamber_Temp_degC_f = list(chain.from_iterable(Chamber_Temp_degC))


final_timestamp = []
final_timestamp = list(chain.from_iterable(TimeStamp_f))


#create dataframe for charge and discharge cycles at 25 degree
df_1 = pd.DataFrame(list(zip(final_timestamp,Voltage_f,Current_f,Ah_f,Wh_f,Power_f,Battery_Temp_degC_f,Time_f,Chamber_Temp_degC_f)),columns=['TimeStamp','Voltage','Current',
                                                               'Ah','Wh','Power','Battery_Temp_degC','Time',
                                                               'Chamber_Temp_degC'])
df_1['TimeStamp']=df_1['TimeStamp'].apply(lambda x : pd.to_datetime(str(x)))
df_1 = df_1.sort_values(by='TimeStamp',ascending=True)

# %%
df_1 #dataframe with consecutive charge and discharge cycles at 25 degree
# Out:
#                TimeStamp  Voltage  ...         Time  Chamber_Temp_degC
# 0    2017-03-11 08:25:11  4.17497  ...     0.000000               25.0
# 1    2017-03-11 08:47:03  4.17497  ...  1311.658003               25.0
# 17   2017-03-12 11:58:58  2.90813  ...     0.000000               25.0
# 18   2017-03-12 11:59:58  2.92486  ...    60.006997               25.0
# 19   2017-03-12 12:00:58  2.93258  ...   120.000999               25.0
# ...                  ...      ...  ...          ...                ...
# 2349 2017-04-29 15:03:38  4.18849  ...  6971.036007                0.0
# 2350 2017-04-29 15:04:38  4.18784  ...  7031.036999                0.0
# 2351 2017-04-29 15:04:38  4.18784  ...  7031.036999                0.0
# 2352 2017-04-29 15:04:44  4.18784  ...  7036.051999                0.0
# 2353 2017-04-29 15:04:44  4.18784  ...  7036.058004                0.0
#
# [2354 rows x 9 columns]

# %%
df_1['DOD'] = (df_1['Ah']*100)/2.9 #adding depth of discharge 
df_1['SOC'] = 100 - df_1['DOD'].abs() #adding SOC - State of Charge in the discharge profile

# %%
print(df_1.shape) #2354 rows and 11 columns in df_1 for dataframe with charge/discharge cycles
df_1.head()
# Out:
# (2354, 11)
#              TimeStamp  Voltage  Current  ...  Chamber_Temp_degC  DOD    SOC
# 0  2017-03-11 08:25:11  4.17497      0.0  ...               25.0  0.0  100.0
# 1  2017-03-11 08:47:03  4.17497      0.0  ...               25.0  0.0  100.0
# 17 2017-03-12 11:58:58  2.90813      0.0  ...               25.0  0.0  100.0
# 18 2017-03-12 11:59:58  2.92486      0.0  ...               25.0  0.0  100.0
# 19 2017-03-12 12:00:58  2.93258      0.0  ...               25.0  0.0  100.0
#
# [5 rows x 11 columns]

# %%
#plot figures w.r.t charges and pauses in 25 degree

fig = plt.figure()
fig.suptitle('Voltage Vs Time for discharge in charge/discharge cycles')
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.plot(df_1['TimeStamp'],df_1['Voltage'])
plt.show()

fig = plt.figure()
fig.suptitle('DOD Vs Time for discharge in charge/discharge cycles')
plt.xlabel('Time')
plt.ylabel('DOD')
plt.plot(df_1['TimeStamp'],df_1['DOD'])
plt.show()

fig = plt.figure()
fig.suptitle('State of Charge Vs Time in charge/discharge cycles')
plt.xlabel('Time')
plt.ylabel('SOC')
plt.plot(df_1['TimeStamp'],df_1['SOC'])
plt.show()

# %% [markdown]
# **So far these are the data obtained from the 5 pulse HPPC tests with charge/discharge cycles. At this point EIS test was done at respective SOC values of the cell to find the equivalent impedances at each SOC level.
# So, in next phase lets import the EIS data and fetch the Impedances for each SOC level.**

# %%
# EIS Spectroscopy data at 25 degree
rows_to_skip = list(range(0,25)) #skipping the first 25 rows of the csv data which contained the basic constant parameters of the cell and EIS description


col_list = ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 
            'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 
            'AhAccu', 'Energy', 'StartFreq', 'EndFreq', 'SetFreq', 'AAcMax',
            'VAcMin', 'VAcMax', 'mvIdeal', 'Go', 'Status', 'U1', 'Zreal1',
            'Zimg1', 'ActFreq', 'EisError', 'AACStart', 'MinIntervalTime',
            'CountOfPeriods', 'UIdeal', 'AStart', 'MinDuration', 'MinPeriods',
            'RemTime', 'VRelativ', 'AAmplitude', 'Betrag', 'Phase', 'ChamberT',
            'ChamberSP','Temp45']

EIS_25_1 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00001.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_1.columns = [''] * len(EIS_25_1.columns)
EIS_25_1 = EIS_25_1.iloc[2:,:-1]
EIS_25_1.reset_index(inplace=True)
EIS_25_1.columns = col_list

EIS_25_2 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00002.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_2.columns = [''] * len(EIS_25_2.columns)
EIS_25_2 = EIS_25_2.iloc[2:,:-1]
EIS_25_2.reset_index(inplace=True)
EIS_25_2.columns = col_list

EIS_25_3 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00003.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_3.columns = [''] * len(EIS_25_3.columns)
EIS_25_3 = EIS_25_3.iloc[2:,:-1]
EIS_25_3.reset_index(inplace=True)
EIS_25_3.columns = col_list

EIS_25_4 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00004.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_4.columns = [''] * len(EIS_25_4.columns)
EIS_25_4 = EIS_25_4.iloc[2:,:-1]
EIS_25_4.reset_index(inplace=True)
EIS_25_4.columns = col_list


EIS_25_5 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00005.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_5.columns = [''] * len(EIS_25_5.columns)
EIS_25_5 = EIS_25_5.iloc[2:,:-1]
EIS_25_5.reset_index(inplace=True)
EIS_25_5.columns = col_list

EIS_25_6 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00006.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_6.columns = [''] * len(EIS_25_6.columns)
EIS_25_6 = EIS_25_6.iloc[2:,:-1]
EIS_25_6.reset_index(inplace=True)
EIS_25_6.columns = col_list

EIS_25_7 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00007.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_7.columns = [''] * len(EIS_25_7.columns)
EIS_25_7 = EIS_25_7.iloc[2:,:-1]
EIS_25_7.reset_index(inplace=True)
EIS_25_7.columns = col_list


EIS_25_8 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00008.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_8.columns = [''] * len(EIS_25_8.columns)
EIS_25_8 = EIS_25_8.iloc[2:,:-1]
EIS_25_8.reset_index(inplace=True)
EIS_25_8.columns = col_list


EIS_25_9 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00009.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_9.columns = [''] * len(EIS_25_9.columns)
EIS_25_9 = EIS_25_9.iloc[2:,:-1]
EIS_25_9.reset_index(inplace=True)
EIS_25_9.columns = col_list

EIS_25_10 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00010.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_10.columns = [''] * len(EIS_25_10.columns)
EIS_25_10 = EIS_25_10.iloc[2:,:-1]
EIS_25_10.reset_index(inplace=True)
EIS_25_10.columns = col_list

EIS_25_11 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00011.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_11.columns = [''] * len(EIS_25_11.columns)
EIS_25_11 = EIS_25_11.iloc[2:,:-1]
EIS_25_11.reset_index(inplace=True)
EIS_25_11.columns = col_list

EIS_25_12 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00012.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_12.columns = [''] * len(EIS_25_12.columns)
EIS_25_12 = EIS_25_12.iloc[2:,:-1]
EIS_25_12.reset_index(inplace=True)
EIS_25_12.columns = col_list

EIS_25_13 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00013.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_13.columns = [''] * len(EIS_25_13.columns)
EIS_25_13 = EIS_25_13.iloc[2:,:-1]
EIS_25_13.reset_index(inplace=True)
EIS_25_13.columns = col_list


EIS_25_14 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_EIS00014.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_14.columns = [''] * len(EIS_25_14.columns)
EIS_25_14 = EIS_25_14.iloc[2:,:-1]
EIS_25_14.reset_index(inplace=True)
EIS_25_14.columns = col_list

EIS_25_15 = pd.read_csv("/content/drive/MyDrive/Data science/Panasonic 18650PF Data/Panasonic 18650PF Data/25degC/EIS/3541_TS003152.csv",skiprows=rows_to_skip,delimiter=';')
EIS_25_15.columns = [''] * len(EIS_25_15.columns)
EIS_25_15 = EIS_25_15.iloc[2:,:-1]
EIS_25_15.reset_index(inplace=True)
EIS_25_15.columns = col_list

EIS_data_25 = pd.concat([EIS_25_1,EIS_25_2,EIS_25_3,EIS_25_4,EIS_25_5,EIS_25_6,
                        EIS_25_7,EIS_25_8,EIS_25_9,EIS_25_10,EIS_25_11,EIS_25_12,
                        EIS_25_13,EIS_25_14,EIS_25_15],axis=0,ignore_index=True)

EIS_data_25['Time Stamp']=EIS_data_25['Time Stamp'].apply(lambda x : pd.to_datetime(str(x)))
EIS_data_25[["Zreal1", "Zimg1",'AhAccu']] = EIS_data_25[["Zreal1", "Zimg1",'AhAccu']].apply(pd.to_numeric)

# %%
print(EIS_data_25.shape) #dataframe all the EIS data at 25 degree
EIS_data_25.head() #771 rows and 41 columns of the data
# Out:
# (771, 41)
#            Time Stamp Step Status  ...  ChamberT ChamberSP    Temp45
# 0 2017-04-27 08:52:52   37    EIS  ...  25.00000  25.00000  26.85486
# 1 2017-04-27 08:53:03   37    EIS  ...  25.00000  25.00000  26.85486
# 2 2017-04-27 08:53:14   37    EIS  ...  25.00000  25.00000  26.85486
# 3 2017-04-27 08:53:24   37    EIS  ...  25.00000  25.00000  26.85486
# 4 2017-04-27 08:53:35   37    EIS  ...  25.00000  25.00000  26.85486
#
# [5 rows x 41 columns]

# %%
#Determing the SOC at all the EIS cycles conducted at 25 degree battery chamber temp
EIS_data_25['SOC']=100-(100*EIS_data_25['AhAccu']/2.9).abs()

# %%
fig = plt.figure()
fig.suptitle('EIS - SOC Vs Time at 25 degree C')
plt.xlabel('Time')
plt.ylabel('SOC')
plt.plot(EIS_data_25['Time Stamp'],EIS_data_25['SOC'])
plt.show()

fig = plt.figure()
fig.suptitle('EIS - Impedance Vs Time at 25 degree C')
plt.xlabel('Time')
plt.ylabel('Z Real')
plt.plot(EIS_data_25['Time Stamp'],EIS_data_25['Zreal1'])
plt.show()

fig = plt.figure()
fig.suptitle('EIS - Impedance Vs SOC at 25 degree C')
plt.xlabel('SOC')
plt.ylabel('Z Real')
plt.plot(EIS_data_25['SOC'],EIS_data_25['Zreal1'])
plt.show()

# %%
# EIS cycles done at 100,95,90,80,70....10,0 SOC%


EIS_data_25['SOC'] = (round(EIS_data_25['SOC'])) #SOC at EIS Cycles at 25 degree

Impedance_list = [] # to store avg impendance values at SOC s of 100,95,90,....

#taking the mean of the impedances at respective SOC levels
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==100.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==95.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==90.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==80.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==70.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==60.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==50.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==40.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==30.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==20.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==15.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==10.0]['Zreal1'].mean())
Impedance_list.append(EIS_data_25[EIS_data_25.SOC==5.0]['Zreal1'].mean())

# %%
print(Impedance_list) #stored Impedance list 
SOC_list = [100.0,95.0,90.0,80.0,70.0,60.0,50.0,40.0,30.0,20.0,15.0,10.0,5.0,0.0]
print(SOC_list) #stored given SOCs from EIS cycles

#create dicitionary of SOC and Impedance values
#dict_z = {a:b for a,b in zip(SOC_list,Impedance_list)}
#print(dict_z)
# Out:
# [41.20026545454545, 34.28295236363636, 31.704757636363635, 30.062045636363635, 29.64673490909091, 29.54569909090909, 28.402136727272726, 28.868327636363645, 30.586624000000008, 32.90274581818182, 37.515412, 46.41362072727274, 57.02380945454545]
# [100.0, 95.0, 90.0, 80.0, 70.0, 60.0, 50.0, 40.0, 30.0, 20.0, 15.0, 10.0, 5.0, 0.0]

# %% [markdown]
# **So now, we have obtained the Impedances for the Respective SOC levels from the EIS Data.
# Next step will be to analyse the 9 drive cycle charge discharge profile. <br>But here we will analyse the Drive cycles of Cycle 1 ,2,3 and 4 as they contain a mix of all theUS06, HWFET, UDDS, LA92, and Neural Network drive cycles. <br>Neural Network drive cycle consists of combination of portions of US06 and LA92 drive cycle, and was designed to have some additional dynamics which may be useful for training neural networks**

# %%
TimeStamp_d=[];Voltage_d= [];Current_d = [];Ah_d = [];Wh_d=[];Power_d=[];Battery_Temp_degC_d=[];
Time_d=[];Chamber_Temp_degC_d=[];

TimeStamp_f_d,Voltage_f_d,Current_f_d,Ah_f_d,Wh_f_d,Power_f_d,Battery_Temp_degC_f_d,Time_f_d,Chamber_Temp_degC_f_d = ([],)*9

from itertools import chain

for i in range(0,3):
    TimeStamp_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][0])))
    Voltage_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][1])))
    Current_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][2])))  
    Ah_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][3])))        
    Wh_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][4])))
    Power_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][5])))
    Battery_Temp_degC_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][6])))
    Time_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][7])))
    Chamber_Temp_degC_d.append(list(chain.from_iterable(deg_25_drives[i]['meas'][0][0][8])))


#unzipping all the list elements in the final lists to form dataframe
TimeStamp_f_d= list(chain.from_iterable(TimeStamp_d))
Voltage_f_d = list(chain.from_iterable(Voltage_d))
Current_f_d = list(chain.from_iterable(Current_d))
Ah_f_d = list(chain.from_iterable(Ah_d))
Wh_f_d = list(chain.from_iterable(Wh_d))
Power_f_d = list(chain.from_iterable(Power_d))
Battery_Temp_degC_f_d = list(chain.from_iterable(Battery_Temp_degC_d))
Time_f_d = list(chain.from_iterable(Time_d))
Chamber_Temp_degC_f_d = list(chain.from_iterable(Chamber_Temp_degC_d))


final_timestamp_d = []
final_timestamp_d = list(chain.from_iterable(TimeStamp_f_d))

df_drives_25deg = pd.DataFrame(list(zip(final_timestamp_d,Voltage_f_d,Current_f_d,Ah_f_d,Wh_f_d,Power_f_d,Battery_Temp_degC_f_d,Time_f_d,Chamber_Temp_degC_f_d)),columns=['TimeStamp','Voltage','Current',
                                                               'Ah','Wh','Power','Battery_Temp_degC','Time',
                                                               'Chamber_Temp_degC'])
df_drives_25deg['TimeStamp']=df_drives_25deg['TimeStamp'].apply(lambda x : pd.to_datetime(str(x)))
df_drives_25deg = df_drives_25deg.sort_values(by='TimeStamp',ascending=True)

# %%
df_drives_25deg['DOD'] = ((df_drives_25deg['Ah']*100)/2.9).abs() #adding depth of discharge 
df_drives_25deg['SOC'] = 100 - df_drives_25deg['DOD'].abs() #adding SOC - State of Charge in the discharge profile

# %%
#dataframe with all the drive cycles conducted at 25 degree temp
print(df_drives_25deg.shape)
df_drives_25deg.head()
# Out:
# (323350, 11)
#             TimeStamp  Voltage  ...       DOD         SOC
# 0 2017-03-18 02:17:35  4.14585  ...  0.000000  100.000000
# 1 2017-03-18 02:17:35  4.10532  ...  0.001724   99.998276
# 2 2017-03-18 02:17:35  4.08666  ...  0.003448   99.996552
# 3 2017-03-18 02:17:35  4.08087  ...  0.005172   99.994828
# 4 2017-03-18 02:17:35  4.07765  ...  0.007241   99.992759
#
# [5 rows x 11 columns]

# %%
#plot figures w.r.t charges and pauses in 25 degree

fig = plt.figure()
fig.suptitle('Voltage Vs Time  in 4 consecutive drive cycles')
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.plot(df_drives_25deg['TimeStamp'],df_drives_25deg['Voltage'])
plt.show()

fig = plt.figure()
fig.suptitle('Voltage Vs DOD for 4 drive cycles')
plt.xlabel('DOD')
plt.ylabel('Voltage')
plt.plot(df_drives_25deg['DOD'],df_drives_25deg['Voltage'])
plt.show()

fig = plt.figure()
fig.suptitle('Voltage Vs State of Charge for 4 drive cycles')
plt.xlabel('SOC')
plt.ylabel('Voltage')
plt.plot(df_drives_25deg['SOC'],df_drives_25deg['Voltage'])
plt.show()

fig = plt.figure()
fig.suptitle('Power Vs DOD of Charge 4 drive cycles')
plt.xlabel('DOD')
plt.ylabel('Power')
plt.plot(df_drives_25deg['DOD'],df_drives_25deg['Power'])
plt.show()

# %%
print (df_drives_25deg['Voltage'].min()) #2.49 V is the minimum voltage
print (df_drives_25deg['Voltage'].max()) #4.23 V is the maximum voltage
# we will try to count the cycles covered in these 9 consecutive drive cycles by observing the 
#charging and discharging pattern 
#during charging - current is positive

cycle_cnt = [] #list to store the cycles
cnt =1         #cycle counts
for x in range(0,len(df_drives_25deg['Current'])):
    cycle_cnt.append(cnt)
    if((df_drives_25deg['Current'][x]>0 and df_drives_25deg['Current'][x+1]<0) or 
       (df_drives_25deg['Current'][x]<0 and df_drives_25deg['Current'][x+1]>0) ):
        cnt = (cnt+1);

df_drives_25deg['cycles']=cycle_cnt #creating a column of cycles in df_drives_25deg
# Out:
# 2.50205
# 4.21744

# %%
fig = plt.figure()
fig.suptitle('Voltage Vs Cycles  in 4 consecutive drive cycles')
plt.xlabel('Cycles')
plt.ylabel('Voltage')
plt.plot(df_drives_25deg['cycles'],df_drives_25deg['Voltage'])
plt.show()
fig = plt.figure()
fig.suptitle('DOD Vs Cycles  in 4 consecutive drive cycles')
plt.xlabel('Cycles')
plt.ylabel('DOD')
plt.plot(df_drives_25deg['cycles'],df_drives_25deg['DOD'])
plt.show()
fig = plt.figure()
fig.suptitle('SOC Vs Cycles  in 4 consecutive drive cycles')
plt.xlabel('Cycles')
plt.ylabel('SOC')
plt.plot(df_drives_25deg['cycles'],df_drives_25deg['SOC'])
plt.show()

# %%
#impedance insertion as per SOC in df_drives_25_deg
df_drives_25deg['SOC'] = (5*(round(df_drives_25deg['SOC']/5,1).astype(int))).astype(float)
df_drives_25deg.reset_index(inplace=True,drop=True)
dummy_list = []
df_drives_25deg.reset_index()
for i in range(df_drives_25deg.shape[0]):
    if(df_drives_25deg['SOC'][i]<=5.0):
        dummy_list.append(Impedance_list[12])
    elif(df_drives_25deg['SOC'][i]<=10.0):
        dummy_list.append(Impedance_list[11])
    elif(df_drives_25deg['SOC'][i]<=15.0):
        dummy_list.append(Impedance_list[10])
    elif(df_drives_25deg['SOC'][i]<=20.0):
        dummy_list.append(Impedance_list[9])
    elif(df_drives_25deg['SOC'][i]<=30.0):
        dummy_list.append(Impedance_list[8])
    elif(df_drives_25deg['SOC'][i]<=40.0):
        dummy_list.append(Impedance_list[7])
    elif(df_drives_25deg['SOC'][i]<=50.0):
        dummy_list.append(Impedance_list[6])
    elif(df_drives_25deg['SOC'][i]<=60.0):
        dummy_list.append(Impedance_list[5])
    elif(df_drives_25deg['SOC'][i]<=70.0):
        dummy_list.append(Impedance_list[4])
    elif(df_drives_25deg['SOC'][i]<=80.0):
        dummy_list.append(Impedance_list[3]) 
    elif(df_drives_25deg['SOC'][i]<=90.0):
        dummy_list.append(Impedance_list[2])
    elif(df_drives_25deg['SOC'][i]<=95.0):
        dummy_list.append(Impedance_list[1])  
    elif(df_drives_25deg['SOC'][i]<=100.0):
        dummy_list.append(Impedance_list[0])

# %%
#adding impedances for 
df_drives_25deg['Impedance'] = dummy_list
df_drives_25deg['Impedance'] = round(df_drives_25deg['Impedance'],2)

# %%
df_drives_25deg.head()
# Out:
#             TimeStamp  Voltage  Current  ...    SOC  cycles  Impedance
# 0 2017-03-18 02:17:35  4.14585 -1.81290  ...  100.0       1       41.2
# 1 2017-03-18 02:17:35  4.10532 -1.83249  ...  100.0       1       41.2
# 2 2017-03-18 02:17:35  4.08666 -1.85046  ...  100.0       1       41.2
# 3 2017-03-18 02:17:35  4.08087 -1.85781  ...  100.0       1       41.2
# 4 2017-03-18 02:17:35  4.07765 -1.86353  ...  100.0       1       41.2
#
# [5 rows x 13 columns]

# %%
fig = plt.figure()
fig.suptitle('Impedance Vs Cycles  in 4 consecutive drive cycles')
plt.xlabel('Cycles')
plt.ylabel('Impedance')
plt.plot(df_drives_25deg['cycles'],df_drives_25deg['Impedance'])
plt.show()

# %%
#marking the point of start of discharging after the battery has been loaded to the full capacity
df_discharge = []

for x in range(len(df_drives_25deg['Current'])):
    if (df_drives_25deg['Current'][x]>0 and df_drives_25deg['Current'][x+1]<0):
        df_discharge.append(1)
    else:
            df_discharge.append(0)
            
df_drives_25deg['discharge'] = df_discharge

# %%
min(set(df_drives_25deg[df_drives_25deg['discharge']==1]['Impedance']))
# Out:
# 28.4

# %% [markdown]
# ##### As observed 28.4 mOhms is the minimum reistance at full load capacity of the battery. So as the charge discharge cycles continue the value of the Impedance will increase at each full load capacity. So to calculate the State of Health we will take the percentage increase in resistances at full load capacity and from there the RUL can be calculated within 70-80 % of the SOH.

# %%
impedance_change_percent = []
soh = [] #list of state of health
count_a = 0;
count_b = 0;
min_impedance = df_drives_25deg['Impedance'].min();

for i in range(len(df_drives_25deg['discharge'])):
    if(df_drives_25deg['discharge'][i] == 1):
        count_a = (df_drives_25deg['Impedance'][i] - min_impedance)
        impedance_change_percent.append(count_a/min_impedance * 100)
    else:
        impedance_change_percent.append(count_a/min_impedance * 100)

df_drives_25deg['Impedance_change'] = impedance_change_percent
#df_drives_25deg['Impedance_change'] = round(df_drives_25deg['Impedance_change'],2)
df_drives_25deg['SOH'] = 100.0 - (df_drives_25deg['Impedance_change'])

# %%
#considering the last 600 cycles in the 4 drive cycles for creating the ML model
df_drives_25deg = df_drives_25deg[df_drives_25deg['cycles']>=1600] 
df_drives_25deg.shape
# Out:
# (91439, 16)

# %%
fig = plt.figure()
fig.suptitle('SOH Vs Cycles  in Drive cycle 4')
plt.xlabel('Cycles')
plt.ylabel('SOH')
plt.plot(df_drives_25deg['cycles'],df_drives_25deg['SOH'])
plt.show()

# %%
df_drives_25deg['cycles']=(1601 - df_drives_25deg['cycles']).abs() #resetting the cycle count from 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_drives_25deg.head()
# Out:
#                  TimeStamp  Voltage  ...  Impedance_change       SOH
# 231911 2017-03-19 09:25:52  3.96201  ...           5.84507  94.15493
# 231912 2017-03-19 09:25:52  3.96201  ...           5.84507  94.15493
# 231913 2017-03-19 09:25:52  3.96073  ...           5.84507  94.15493
# 231914 2017-03-19 09:25:52  3.96266  ...           5.84507  94.15493
# 231915 2017-03-19 09:25:53  3.92582  ...           5.84507  94.15493
#
# [5 rows x 16 columns]

# %%
#final dataframe
df_final = df_drives_25deg[['Voltage','Current','Battery_Temp_degC','SOC','cycles','SOH']]
df_final.reset_index(drop=True,inplace=True)

# %%
#shape of df_final
print(df_final.shape)
print(df_final['cycles'].max())
df_final.head()
# Out:
# (91439, 6)
# 575
#    Voltage  Current  Battery_Temp_degC   SOC  cycles       SOH
# 0  3.96201  0.93916           28.36550  80.0       1  94.15493
# 1  3.96201  0.93916           28.36550  80.0       1  94.15493
# 2  3.96073  0.93998           28.36550  80.0       1  94.15493
# 3  3.96266  0.93916           28.36550  80.0       1  94.15493
# 4  3.92582 -2.34860           28.35429  80.0       1  94.15493

# %% [markdown]
# **The remaining Useful life of the battery can be calculated in terms of cycles where SOH lies between 80-70%. So taking the inputs of Voltage,Current,battery temperature and State of charge , we will have to predict the cycles and SOH which will help us estimate the Remaining Useful life(RUL) of the battery. <br>Please note that the battery chamber temperature is kept at 25 degree C for this model</br>**

# %%
fig = plt.figure()
fig.suptitle('SOH Vs Cycles Dataset for 575 cycles')
plt.xlabel('Cycles')
plt.ylabel('SOH')
plt.plot(df_final['cycles'],df_final['SOH'])
plt.show()

# %%
#checking for null values
df_final.isna().any() 
df_final.isnull().any()
# Out:
# Voltage              False
# Current              False
# Battery_Temp_degC    False
# SOC                  False
# cycles               False
# SOH                  False
# dtype: bool

# %%
#dropping duplicate values
df_final.drop_duplicates(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_final['Current'] = df_final['Current'].abs() #taking the absolute values of the current
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#correlation matrix for the columns 
import seaborn as sns
corr_matrix = df_final.corr()
sns.heatmap(corr_matrix, 
        xticklabels=corr_matrix.columns,
        yticklabels=corr_matrix.columns)

# %% [markdown]
# Since State of Charge and Voltage is highly correlated with the cycles which we tend to predict.So,dropping SOC since it has high correlation.

# %%
df_final = df_final[['Current','Battery_Temp_degC','cycles','SOH']]
corr_matrix = df_final.corr()
sns.heatmap(corr_matrix, 
        xticklabels=corr_matrix.columns,
        yticklabels=corr_matrix.columns)

# %% [markdown]
# Train - validation - test split

# %%
# !pip install fast-ml #using fast-ml lib for EDA analysis and data preparation
# Out:
# Requirement already satisfied: fast-ml in /usr/local/lib/python3.7/dist-packages (3.68)

# %%
from fast_ml import eda

summary_df = eda.df_info(df_final)
summary_df
# Out:
#                   data_type data_type_grp  ... num_missing perc_missing
# Current             float64     Numerical  ...           0            0
# Battery_Temp_degC   float64     Numerical  ...           0            0
# cycles                int64     Numerical  ...           0            0
# SOH                 float64     Numerical  ...           0            0
#
# [4 rows x 6 columns]

# %%
df_final.shape #final rows and columns of the dataframe
# Out:
# (59183, 4)

# %%
#Train validation test split

from fast_ml.model_development import train_valid_test_split

#split the dataset into train-valid-test in ratios of 80:10:10

X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(df_final, target = 'SOH', 
                                                                            train_size=0.8, valid_size=0.1, test_size=0.1)


print("train inputs",X_train.shape) # shape of the train inputs
print("train outputs",y_train.shape) # shape of the train output
print("valid inputs",X_valid.shape) # shape of the valid input
print('valid outputs',y_valid.shape) # shape of the valid output
print('test inputs',X_test.shape)  # shape of the test input
print('test outputs',y_test.shape)  # shape of the test output
# Out:
# train inputs (47346, 3)
# train outputs (47346,)
# valid inputs (5918, 3)
# valid outputs (5918,)
# test inputs (5919, 3)
# test outputs (5919,)

# %% [markdown]
# Neural Network Model architecture design and parameterization for training the model

# %%
! pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.7.0)

# %%
# imports
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy
from tensorflow.keras.optimizers import Adam
import keras
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
# Create model
model = Sequential()
model.add(Dense(128, activation="relu", input_dim=3))
model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(4, activation="relu"))
# Since the regression is performed, a Dense layer containing a single neuron with a linear activation function.
# Typically ReLu-based activation are used but since it is performed regression, it is needed a linear activation.
model.add(Dense(1, activation="linear"))

# Compile model: The model is initialized with the Adam optimizer and then it is compiled.
model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 100))

# %%
# Patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=1000, batch_size=100, verbose=2, callbacks=[es])

# Calculate predictions
PredTrainSet = model.predict(X_train)
PredValSet = model.predict(X_valid)


# Save predictions
numpy.savetxt("trainresults.csv", PredTrainSet, delimiter=",")
numpy.savetxt("valresults.csv", PredValSet, delimiter=",")
# Out:
# Epoch 1/1000
# 474/474 - 2s - loss: 1264.1708 - val_loss: 60.7178 - 2s/epoch - 4ms/step
# Epoch 2/1000
# 474/474 - 1s - loss: 53.2432 - val_loss: 51.8528 - 925ms/epoch - 2ms/step
# Epoch 3/1000
# 474/474 - 1s - loss: 49.1083 - val_loss: 53.7267 - 994ms/epoch - 2ms/step
# Epoch 4/1000
# 474/474 - 1s - loss: 48.9613 - val_loss: 49.7305 - 927ms/epoch - 2ms/step
# Epoch 5/1000
# 474/474 - 1s - loss: 47.2620 - val_loss: 48.9728 - 999ms/epoch - 2ms/step
# Epoch 6/1000
# 474/474 - 1s - loss: 46.6998 - val_loss: 46.4938 - 907ms/epoch - 2ms/step
# Epoch 7/1000
# 474/474 - 1s - loss: 46.0009 - val_loss: 46.7057 - 1s/epoch - 2ms/step
# Epoch 8/1000
# 474/474 - 1s - loss: 44.6806 - val_loss: 46.8393 - 919ms/epoch - 2ms/step
# Epoch 9/1000
# 474/474 - 1s - loss: 46.2603 - val_loss: 46.1781 - 925ms/epoch - 2ms/step
# Epoch 10/1000
# 474/474 - 1s - loss: 44.2403 - val_loss: 48.4894 - 988ms/epoch - 2ms/step
# Epoch 11/1000
# 474/474 - 1s - loss: 44.7734 - val_loss: 46.8346 - 921ms/epoch - 2ms/step
# Epoch 12/1000
# 474/474 - 1s - loss: 43.4047 - val_loss: 45.9685 - 911ms/epoch - 2ms/step
# Epoch 13/1000
# 474/474 - 1s - loss: 45.0562 - val_loss: 45.9999 - 919ms/epoch - 2ms/step
# Epoch 14/1000
# 474/474 - 1s - loss: 43.5840 - val_loss: 49.1121 - 973ms/epoch - 2ms/step
# Epoch 15/1000
# 474/474 - 1s - loss: 44.2174 - val_loss: 48.6854 - 941ms/epoch - 2ms/step
# Epoch 16/1000
# 474/474 - 1s - loss: 43.4708 - val_loss: 59.8354 - 902ms/epoch - 2ms/step
# Epoch 17/1000
# 474/474 - 1s - loss: 43.6117 - val_loss: 42.4613 - 920ms/epoch - 2ms/step
# Epoch 18/1000
# 474/474 - 1s - loss: 44.2134 - val_loss: 45.3675 - 889ms/epoch - 2ms/step
# Epoch 19/1000
# 474/474 - 1s - loss: 43.2336 - val_loss: 47.5184 - 902ms/epoch - 2ms/step
# Epoch 20/1000
# 474/474 - 1s - loss: 42.0265 - val_loss: 41.3797 - 907ms/epoch - 2ms/step
# Epoch 21/1000
# 474/474 - 1s - loss: 41.9157 - val_loss: 42.6913 - 972ms/epoch - 2ms/step
# Epoch 22/1000
# 474/474 - 1s - loss: 42.5066 - val_loss: 41.2065 - 919ms/epoch - 2ms/step
# Epoch 23/1000
# 474/474 - 1s - loss: 40.2849 - val_loss: 41.8231 - 994ms/epoch - 2ms/step
# Epoch 24/1000
# 474/474 - 1s - loss: 42.0976 - val_loss: 41.4647 - 1s/epoch - 2ms/step
# Epoch 25/1000
# 474/474 - 1s - loss: 40.4686 - val_loss: 46.1211 - 987ms/epoch - 2ms/step
# Epoch 26/1000
# 474/474 - 1s - loss: 42.4432 - val_loss: 46.7958 - 910ms/epoch - 2ms/step
# Epoch 27/1000
# 474/474 - 1s - loss: 39.9598 - val_loss: 41.5008 - 929ms/epoch - 2ms/step
# Epoch 28/1000
# 474/474 - 1s - loss: 39.1198 - val_loss: 45.7716 - 905ms/epoch - 2ms/step
# Epoch 29/1000
# 474/474 - 1s - loss: 40.7141 - val_loss: 46.3752 - 994ms/epoch - 2ms/step
# Epoch 30/1000
# 474/474 - 1s - loss: 41.1685 - val_loss: 39.0128 - 980ms/epoch - 2ms/step
# Epoch 31/1000
# 474/474 - 1s - loss: 39.4698 - val_loss: 51.7028 - 894ms/epoch - 2ms/step
# Epoch 32/1000
# 474/474 - 1s - loss: 39.9453 - val_loss: 39.7081 - 925ms/epoch - 2ms/step
# Epoch 33/1000
# 474/474 - 1s - loss: 39.3259 - val_loss: 37.7295 - 926ms/epoch - 2ms/step
# Epoch 34/1000
# 474/474 - 1s - loss: 36.9616 - val_loss: 38.3124 - 892ms/epoch - 2ms/step
# Epoch 35/1000
# 474/474 - 1s - loss: 38.9888 - val_loss: 35.6177 - 905ms/epoch - 2ms/step
# Epoch 36/1000
# 474/474 - 1s - loss: 36.8086 - val_loss: 38.9067 - 1s/epoch - 2ms/step
# Epoch 37/1000
# 474/474 - 1s - loss: 37.1023 - val_loss: 55.1735 - 1s/epoch - 2ms/step
# Epoch 38/1000
# 474/474 - 1s - loss: 37.0463 - val_loss: 44.5618 - 951ms/epoch - 2ms/step
# Epoch 39/1000
# 474/474 - 1s - loss: 36.0571 - val_loss: 35.1318 - 917ms/epoch - 2ms/step
# Epoch 40/1000
# 474/474 - 1s - loss: 37.2519 - val_loss: 43.0777 - 964ms/epoch - 2ms/step
# Epoch 41/1000
# 474/474 - 1s - loss: 36.1596 - val_loss: 43.9512 - 904ms/epoch - 2ms/step
# Epoch 42/1000
# 474/474 - 1s - loss: 35.9496 - val_loss: 33.8600 - 931ms/epoch - 2ms/step
# Epoch 43/1000
# 474/474 - 1s - loss: 36.3318 - val_loss: 33.9711 - 987ms/epoch - 2ms/step
# Epoch 44/1000
# 474/474 - 1s - loss: 36.4230 - val_loss: 35.2711 - 917ms/epoch - 2ms/step
# Epoch 45/1000
# 474/474 - 1s - loss: 36.5584 - val_loss: 37.3249 - 993ms/epoch - 2ms/step
# Epoch 46/1000
# 474/474 - 1s - loss: 36.6403 - val_loss: 32.5668 - 907ms/epoch - 2ms/step
# Epoch 47/1000
# 474/474 - 1s - loss: 35.1085 - val_loss: 32.5508 - 1s/epoch - 2ms/step
# Epoch 48/1000
# 474/474 - 1s - loss: 33.9792 - val_loss: 34.9722 - 1s/epoch - 2ms/step
# Epoch 49/1000
# 474/474 - 1s - loss: 33.9776 - val_loss: 31.5317 - 954ms/epoch - 2ms/step
# Epoch 50/1000
# 474/474 - 1s - loss: 35.2404 - val_loss: 34.3074 - 922ms/epoch - 2ms/step
# Epoch 51/1000
# 474/474 - 1s - loss: 34.0358 - val_loss: 42.1788 - 897ms/epoch - 2ms/step
# Epoch 52/1000
# 474/474 - 1s - loss: 34.9371 - val_loss: 34.1911 - 890ms/epoch - 2ms/step
# Epoch 53/1000
# 474/474 - 1s - loss: 35.1124 - val_loss: 31.8423 - 998ms/epoch - 2ms/step
# Epoch 54/1000
# 474/474 - 1s - loss: 35.9388 - val_loss: 31.6449 - 932ms/epoch - 2ms/step
# Epoch 55/1000
# 474/474 - 1s - loss: 33.0548 - val_loss: 29.5546 - 932ms/epoch - 2ms/step
# Epoch 56/1000
# 474/474 - 1s - loss: 35.4072 - val_loss: 35.3922 - 895ms/epoch - 2ms/step
# Epoch 57/1000
# 474/474 - 1s - loss: 34.6862 - val_loss: 33.9708 - 897ms/epoch - 2ms/step
# Epoch 58/1000
# 474/474 - 1s - loss: 32.3967 - val_loss: 29.4461 - 912ms/epoch - 2ms/step
# Epoch 59/1000
# 474/474 - 1s - loss: 33.8292 - val_loss: 57.7898 - 985ms/epoch - 2ms/step
# Epoch 60/1000
# 474/474 - 1s - loss: 34.1713 - val_loss: 41.4818 - 945ms/epoch - 2ms/step
# Epoch 61/1000
# 474/474 - 1s - loss: 32.7362 - val_loss: 41.3487 - 893ms/epoch - 2ms/step
# Epoch 62/1000
# 474/474 - 1s - loss: 33.2210 - val_loss: 28.0311 - 985ms/epoch - 2ms/step
# Epoch 63/1000
# 474/474 - 1s - loss: 34.1293 - val_loss: 35.4819 - 892ms/epoch - 2ms/step
# Epoch 64/1000
# 474/474 - 1s - loss: 36.0063 - val_loss: 61.1191 - 895ms/epoch - 2ms/step
# Epoch 65/1000
# 474/474 - 1s - loss: 34.5938 - val_loss: 32.4887 - 910ms/epoch - 2ms/step
# Epoch 66/1000
# 474/474 - 1s - loss: 32.2566 - val_loss: 34.3142 - 971ms/epoch - 2ms/step
# Epoch 67/1000
# 474/474 - 1s - loss: 34.9303 - val_loss: 33.4913 - 988ms/epoch - 2ms/step
# Epoch 68/1000
# 474/474 - 1s - loss: 31.8270 - val_loss: 31.6259 - 922ms/epoch - 2ms/step
# Epoch 69/1000
# 474/474 - 1s - loss: 32.8814 - val_loss: 29.2347 - 900ms/epoch - 2ms/step
# Epoch 70/1000
# 474/474 - 1s - loss: 32.1076 - val_loss: 28.9390 - 933ms/epoch - 2ms/step
# Epoch 71/1000
# 474/474 - 1s - loss: 32.6409 - val_loss: 44.6481 - 919ms/epoch - 2ms/step
# Epoch 72/1000
# 474/474 - 1s - loss: 32.1045 - val_loss: 36.2970 - 945ms/epoch - 2ms/step
# Epoch 73/1000
# 474/474 - 1s - loss: 31.1909 - val_loss: 28.0571 - 1s/epoch - 2ms/step
# Epoch 74/1000
# 474/474 - 1s - loss: 32.4259 - val_loss: 27.1783 - 897ms/epoch - 2ms/step
# Epoch 75/1000
# 474/474 - 1s - loss: 33.3983 - val_loss: 33.5610 - 914ms/epoch - 2ms/step
# Epoch 76/1000
# 474/474 - 1s - loss: 31.6173 - val_loss: 34.4034 - 985ms/epoch - 2ms/step
# Epoch 77/1000
# 474/474 - 1s - loss: 33.0190 - val_loss: 32.9268 - 912ms/epoch - 2ms/step
# Epoch 78/1000
# 474/474 - 1s - loss: 31.3256 - val_loss: 26.4811 - 901ms/epoch - 2ms/step
# Epoch 79/1000
# 474/474 - 1s - loss: 31.5331 - val_loss: 28.4598 - 927ms/epoch - 2ms/step
# Epoch 80/1000
# 474/474 - 1s - loss: 29.6665 - val_loss: 27.5644 - 959ms/epoch - 2ms/step
# Epoch 81/1000
# 474/474 - 1s - loss: 31.4661 - val_loss: 28.5906 - 954ms/epoch - 2ms/step
# Epoch 82/1000
# 474/474 - 1s - loss: 29.7761 - val_loss: 40.1237 - 981ms/epoch - 2ms/step
# Epoch 83/1000
# 474/474 - 1s - loss: 30.0436 - val_loss: 30.9670 - 1s/epoch - 2ms/step
# Epoch 84/1000
# 474/474 - 1s - loss: 30.3659 - val_loss: 26.5478 - 923ms/epoch - 2ms/step
# Epoch 85/1000
# 474/474 - 1s - loss: 31.9116 - val_loss: 48.8456 - 988ms/epoch - 2ms/step
# Epoch 86/1000
# 474/474 - 1s - loss: 30.1985 - val_loss: 27.2322 - 990ms/epoch - 2ms/step
# Epoch 87/1000
# 474/474 - 1s - loss: 31.0155 - val_loss: 41.6844 - 992ms/epoch - 2ms/step
# Epoch 88/1000
# 474/474 - 1s - loss: 30.2795 - val_loss: 27.7875 - 913ms/epoch - 2ms/step
# Epoch 89/1000
# 474/474 - 1s - loss: 30.7656 - val_loss: 44.7583 - 914ms/epoch - 2ms/step
# Epoch 90/1000
# 474/474 - 1s - loss: 27.3636 - val_loss: 33.0365 - 974ms/epoch - 2ms/step
# Epoch 91/1000
# 474/474 - 1s - loss: 29.5111 - val_loss: 42.3089 - 921ms/epoch - 2ms/step
# Epoch 92/1000
# 474/474 - 1s - loss: 30.7156 - val_loss: 36.4848 - 910ms/epoch - 2ms/step
# Epoch 93/1000
# 474/474 - 1s - loss: 30.0546 - val_loss: 26.0385 - 993ms/epoch - 2ms/step
# Epoch 94/1000
# 474/474 - 1s - loss: 29.1236 - val_loss: 33.0635 - 908ms/epoch - 2ms/step
# Epoch 95/1000
# 474/474 - 1s - loss: 29.9865 - val_loss: 26.5459 - 907ms/epoch - 2ms/step
# Epoch 96/1000
# 474/474 - 1s - loss: 30.9613 - val_loss: 34.7879 - 942ms/epoch - 2ms/step
# Epoch 97/1000
# 474/474 - 1s - loss: 30.7602 - val_loss: 29.0117 - 922ms/epoch - 2ms/step
# Epoch 98/1000
# 474/474 - 1s - loss: 27.4339 - val_loss: 31.9087 - 874ms/epoch - 2ms/step
# Epoch 99/1000
# 474/474 - 1s - loss: 29.6374 - val_loss: 30.5734 - 991ms/epoch - 2ms/step
# Epoch 100/1000
# 474/474 - 1s - loss: 30.6810 - val_loss: 34.2699 - 910ms/epoch - 2ms/step
# Epoch 101/1000
# 474/474 - 1s - loss: 28.5268 - val_loss: 28.5541 - 977ms/epoch - 2ms/step
# Epoch 102/1000
# 474/474 - 1s - loss: 28.3373 - val_loss: 23.2144 - 912ms/epoch - 2ms/step
# Epoch 103/1000
# 474/474 - 1s - loss: 28.1805 - val_loss: 24.9557 - 921ms/epoch - 2ms/step
# Epoch 104/1000
# 474/474 - 1s - loss: 28.8023 - val_loss: 26.2718 - 906ms/epoch - 2ms/step
# Epoch 105/1000
# 474/474 - 1s - loss: 27.4743 - val_loss: 30.9425 - 1s/epoch - 2ms/step
# Epoch 106/1000
# 474/474 - 1s - loss: 26.9845 - val_loss: 27.9220 - 915ms/epoch - 2ms/step
# Epoch 107/1000
# 474/474 - 1s - loss: 28.6584 - val_loss: 31.7372 - 894ms/epoch - 2ms/step
# Epoch 108/1000
# 474/474 - 1s - loss: 27.5412 - val_loss: 30.3156 - 910ms/epoch - 2ms/step
# Epoch 109/1000
# 474/474 - 1s - loss: 28.2098 - val_loss: 32.8235 - 907ms/epoch - 2ms/step
# Epoch 110/1000
# 474/474 - 1s - loss: 26.4958 - val_loss: 26.0048 - 912ms/epoch - 2ms/step
# Epoch 111/1000
# 474/474 - 1s - loss: 28.4526 - val_loss: 27.1853 - 904ms/epoch - 2ms/step
# Epoch 112/1000
# 474/474 - 1s - loss: 26.8258 - val_loss: 23.1244 - 914ms/epoch - 2ms/step
# Epoch 113/1000
# 474/474 - 1s - loss: 28.9415 - val_loss: 25.7273 - 1s/epoch - 2ms/step
# Epoch 114/1000
# 474/474 - 1s - loss: 27.6001 - val_loss: 25.7197 - 1s/epoch - 2ms/step
# Epoch 115/1000
# 474/474 - 1s - loss: 25.7106 - val_loss: 38.4134 - 969ms/epoch - 2ms/step
# Epoch 116/1000
# 474/474 - 1s - loss: 26.7814 - val_loss: 29.2828 - 896ms/epoch - 2ms/step
# Epoch 117/1000
# 474/474 - 1s - loss: 26.3844 - val_loss: 27.4714 - 921ms/epoch - 2ms/step
# Epoch 118/1000
# 474/474 - 1s - loss: 28.0512 - val_loss: 29.1757 - 927ms/epoch - 2ms/step
# Epoch 119/1000
# 474/474 - 1s - loss: 28.6237 - val_loss: 23.9479 - 1s/epoch - 2ms/step
# Epoch 120/1000
# 474/474 - 1s - loss: 25.4380 - val_loss: 24.8217 - 909ms/epoch - 2ms/step
# Epoch 121/1000
# 474/474 - 1s - loss: 26.3599 - val_loss: 24.5079 - 995ms/epoch - 2ms/step
# Epoch 122/1000
# 474/474 - 1s - loss: 25.3264 - val_loss: 23.9662 - 910ms/epoch - 2ms/step
# Epoch 123/1000
# 474/474 - 1s - loss: 26.5324 - val_loss: 24.6316 - 989ms/epoch - 2ms/step
# Epoch 124/1000
# 474/474 - 1s - loss: 24.9446 - val_loss: 27.5762 - 962ms/epoch - 2ms/step
# Epoch 125/1000
# 474/474 - 1s - loss: 26.8413 - val_loss: 23.5191 - 992ms/epoch - 2ms/step
# Epoch 126/1000
# 474/474 - 1s - loss: 25.7672 - val_loss: 32.4329 - 971ms/epoch - 2ms/step
# Epoch 127/1000
# 474/474 - 1s - loss: 25.7958 - val_loss: 42.6067 - 895ms/epoch - 2ms/step
# Epoch 128/1000
# 474/474 - 1s - loss: 24.8273 - val_loss: 24.9361 - 1s/epoch - 2ms/step
# Epoch 129/1000
# 474/474 - 1s - loss: 26.3721 - val_loss: 22.0278 - 906ms/epoch - 2ms/step
# Epoch 130/1000
# 474/474 - 1s - loss: 27.4020 - val_loss: 27.4601 - 989ms/epoch - 2ms/step
# Epoch 131/1000
# 474/474 - 1s - loss: 25.4676 - val_loss: 22.1238 - 911ms/epoch - 2ms/step
# Epoch 132/1000
# 474/474 - 1s - loss: 25.8540 - val_loss: 23.4303 - 927ms/epoch - 2ms/step
# Epoch 133/1000
# 474/474 - 1s - loss: 25.6343 - val_loss: 24.7229 - 984ms/epoch - 2ms/step
# Epoch 134/1000
# 474/474 - 1s - loss: 25.1748 - val_loss: 36.3320 - 995ms/epoch - 2ms/step
# Epoch 135/1000
# 474/474 - 1s - loss: 25.0094 - val_loss: 21.8741 - 1s/epoch - 2ms/step
# Epoch 136/1000
# 474/474 - 1s - loss: 25.8137 - val_loss: 26.8209 - 907ms/epoch - 2ms/step
# Epoch 137/1000
# 474/474 - 1s - loss: 24.9398 - val_loss: 32.1814 - 911ms/epoch - 2ms/step
# Epoch 138/1000
# 474/474 - 1s - loss: 25.9076 - val_loss: 24.5182 - 894ms/epoch - 2ms/step
# Epoch 139/1000
# 474/474 - 1s - loss: 24.1343 - val_loss: 33.6878 - 1s/epoch - 2ms/step
# Epoch 140/1000
# 474/474 - 1s - loss: 25.9394 - val_loss: 23.1034 - 895ms/epoch - 2ms/step
# Epoch 141/1000
# 474/474 - 1s - loss: 25.0494 - val_loss: 25.1748 - 892ms/epoch - 2ms/step
# Epoch 142/1000
# 474/474 - 1s - loss: 24.6210 - val_loss: 25.9788 - 994ms/epoch - 2ms/step
# Epoch 143/1000
# 474/474 - 1s - loss: 25.3611 - val_loss: 22.9399 - 894ms/epoch - 2ms/step
# Epoch 144/1000
# 474/474 - 1s - loss: 27.1502 - val_loss: 23.1286 - 910ms/epoch - 2ms/step
# Epoch 145/1000
# 474/474 - 1s - loss: 28.3495 - val_loss: 32.7220 - 987ms/epoch - 2ms/step
# Epoch 146/1000
# 474/474 - 1s - loss: 26.1678 - val_loss: 22.9193 - 915ms/epoch - 2ms/step
# Epoch 147/1000
# 474/474 - 1s - loss: 23.9247 - val_loss: 25.4587 - 910ms/epoch - 2ms/step
# Epoch 148/1000
# 474/474 - 1s - loss: 27.1968 - val_loss: 33.5332 - 905ms/epoch - 2ms/step
# Epoch 149/1000
# 474/474 - 1s - loss: 34.0276 - val_loss: 32.8837 - 885ms/epoch - 2ms/step
# Epoch 150/1000
# 474/474 - 1s - loss: 30.6974 - val_loss: 27.7740 - 908ms/epoch - 2ms/step
# Epoch 151/1000
# 474/474 - 1s - loss: 30.0256 - val_loss: 43.1229 - 999ms/epoch - 2ms/step
# Epoch 152/1000
# 474/474 - 1s - loss: 33.9206 - val_loss: 27.0202 - 892ms/epoch - 2ms/step
# Epoch 153/1000
# 474/474 - 1s - loss: 32.0891 - val_loss: 31.0175 - 881ms/epoch - 2ms/step
# Epoch 154/1000
# 474/474 - 1s - loss: 30.4870 - val_loss: 25.4056 - 988ms/epoch - 2ms/step
# Epoch 155/1000
# 474/474 - 1s - loss: 31.7695 - val_loss: 26.5216 - 976ms/epoch - 2ms/step
# Epoch 156/1000
# 474/474 - 1s - loss: 29.1585 - val_loss: 26.0942 - 903ms/epoch - 2ms/step
# Epoch 157/1000
# 474/474 - 1s - loss: 28.4624 - val_loss: 26.5728 - 904ms/epoch - 2ms/step
# Epoch 158/1000
# 474/474 - 1s - loss: 27.0040 - val_loss: 30.8843 - 990ms/epoch - 2ms/step
# Epoch 159/1000
# 474/474 - 1s - loss: 28.1097 - val_loss: 30.6291 - 998ms/epoch - 2ms/step
# Epoch 160/1000
# 474/474 - 1s - loss: 28.4336 - val_loss: 49.0216 - 900ms/epoch - 2ms/step
# Epoch 161/1000
# 474/474 - 1s - loss: 29.6650 - val_loss: 32.0087 - 908ms/epoch - 2ms/step
# Epoch 162/1000
# 474/474 - 1s - loss: 28.0164 - val_loss: 43.1966 - 1s/epoch - 2ms/step
# Epoch 163/1000
# 474/474 - 1s - loss: 27.9961 - val_loss: 25.0214 - 1s/epoch - 2ms/step
# Epoch 164/1000
# 474/474 - 1s - loss: 27.2677 - val_loss: 28.6593 - 946ms/epoch - 2ms/step
# Epoch 165/1000
# 474/474 - 1s - loss: 29.2307 - val_loss: 30.0348 - 925ms/epoch - 2ms/step
# Epoch 166/1000
# 474/474 - 1s - loss: 27.8044 - val_loss: 31.1703 - 1s/epoch - 2ms/step
# Epoch 167/1000
# 474/474 - 1s - loss: 25.7632 - val_loss: 23.1271 - 993ms/epoch - 2ms/step
# Epoch 168/1000
# 474/474 - 1s - loss: 28.1285 - val_loss: 49.0850 - 927ms/epoch - 2ms/step
# Epoch 169/1000
# 474/474 - 1s - loss: 30.6283 - val_loss: 41.3355 - 916ms/epoch - 2ms/step
# Epoch 170/1000
# 474/474 - 1s - loss: 27.8313 - val_loss: 28.4216 - 981ms/epoch - 2ms/step
# Epoch 171/1000
# 474/474 - 1s - loss: 27.4628 - val_loss: 24.8196 - 995ms/epoch - 2ms/step
# Epoch 172/1000
# 474/474 - 1s - loss: 25.9823 - val_loss: 27.6703 - 912ms/epoch - 2ms/step
# Epoch 173/1000
# 474/474 - 1s - loss: 25.7017 - val_loss: 27.9531 - 920ms/epoch - 2ms/step
# Epoch 174/1000
# 474/474 - 1s - loss: 26.5245 - val_loss: 24.0527 - 926ms/epoch - 2ms/step
# Epoch 175/1000
# 474/474 - 1s - loss: 26.4352 - val_loss: 23.3723 - 992ms/epoch - 2ms/step
# Epoch 176/1000
# 474/474 - 1s - loss: 26.4153 - val_loss: 32.2986 - 921ms/epoch - 2ms/step
# Epoch 177/1000
# 474/474 - 1s - loss: 25.3363 - val_loss: 22.9207 - 893ms/epoch - 2ms/step
# Epoch 178/1000
# 474/474 - 1s - loss: 25.9081 - val_loss: 24.2189 - 904ms/epoch - 2ms/step
# Epoch 179/1000
# 474/474 - 1s - loss: 24.9022 - val_loss: 23.0982 - 982ms/epoch - 2ms/step
# Epoch 180/1000
# 474/474 - 1s - loss: 26.7559 - val_loss: 31.1104 - 990ms/epoch - 2ms/step
# Epoch 181/1000
# 474/474 - 1s - loss: 24.7601 - val_loss: 32.8816 - 934ms/epoch - 2ms/step
# Epoch 182/1000
# 474/474 - 1s - loss: 25.6868 - val_loss: 24.6679 - 906ms/epoch - 2ms/step
# Epoch 183/1000
# 474/474 - 1s - loss: 25.4464 - val_loss: 23.3050 - 902ms/epoch - 2ms/step
# Epoch 184/1000
# 474/474 - 1s - loss: 26.1943 - val_loss: 28.5188 - 917ms/epoch - 2ms/step
# Epoch 185/1000
# 474/474 - 1s - loss: 24.9110 - val_loss: 24.3409 - 917ms/epoch - 2ms/step
# Epoch 186/1000
# 474/474 - 1s - loss: 24.0304 - val_loss: 29.8721 - 971ms/epoch - 2ms/step
# Epoch 187/1000
# 474/474 - 1s - loss: 25.0692 - val_loss: 27.4402 - 1s/epoch - 2ms/step
# Epoch 188/1000
# 474/474 - 1s - loss: 24.1092 - val_loss: 27.4240 - 913ms/epoch - 2ms/step
# Epoch 189/1000
# 474/474 - 1s - loss: 24.6331 - val_loss: 22.7395 - 985ms/epoch - 2ms/step
# Epoch 190/1000
# 474/474 - 1s - loss: 27.1894 - val_loss: 23.4226 - 906ms/epoch - 2ms/step
# Epoch 191/1000
# 474/474 - 1s - loss: 25.1289 - val_loss: 24.9098 - 899ms/epoch - 2ms/step
# Epoch 192/1000
# 474/474 - 1s - loss: 25.6344 - val_loss: 21.6190 - 899ms/epoch - 2ms/step
# Epoch 193/1000
# 474/474 - 1s - loss: 25.4905 - val_loss: 21.2295 - 914ms/epoch - 2ms/step
# Epoch 194/1000
# 474/474 - 1s - loss: 23.6929 - val_loss: 26.1890 - 898ms/epoch - 2ms/step
# Epoch 195/1000
# 474/474 - 1s - loss: 26.0250 - val_loss: 23.4175 - 994ms/epoch - 2ms/step
# Epoch 196/1000
# 474/474 - 1s - loss: 24.3685 - val_loss: 25.7044 - 911ms/epoch - 2ms/step
# Epoch 197/1000
# 474/474 - 1s - loss: 22.8226 - val_loss: 25.5538 - 963ms/epoch - 2ms/step
# Epoch 198/1000
# 474/474 - 1s - loss: 24.5492 - val_loss: 33.3681 - 1s/epoch - 2ms/step
# Epoch 199/1000
# 474/474 - 1s - loss: 24.2895 - val_loss: 34.7442 - 897ms/epoch - 2ms/step
# Epoch 200/1000
# 474/474 - 1s - loss: 24.7273 - val_loss: 28.9797 - 920ms/epoch - 2ms/step
# Epoch 201/1000
# 474/474 - 1s - loss: 24.7279 - val_loss: 24.3017 - 921ms/epoch - 2ms/step
# Epoch 202/1000
# 474/474 - 1s - loss: 23.0176 - val_loss: 24.2153 - 906ms/epoch - 2ms/step
# Epoch 203/1000
# 474/474 - 1s - loss: 24.0463 - val_loss: 25.8727 - 905ms/epoch - 2ms/step
# Epoch 204/1000
# 474/474 - 1s - loss: 24.5655 - val_loss: 23.4092 - 981ms/epoch - 2ms/step
# Epoch 205/1000
# 474/474 - 1s - loss: 23.4408 - val_loss: 25.2229 - 994ms/epoch - 2ms/step
# Epoch 206/1000
# 474/474 - 1s - loss: 22.8042 - val_loss: 25.7379 - 964ms/epoch - 2ms/step
# Epoch 207/1000
# 474/474 - 1s - loss: 23.3319 - val_loss: 20.6396 - 904ms/epoch - 2ms/step
# Epoch 208/1000
# 474/474 - 1s - loss: 23.8356 - val_loss: 29.3115 - 912ms/epoch - 2ms/step
# Epoch 209/1000
# 474/474 - 1s - loss: 21.9646 - val_loss: 24.4381 - 987ms/epoch - 2ms/step
# Epoch 210/1000
# 474/474 - 1s - loss: 25.7623 - val_loss: 26.0239 - 903ms/epoch - 2ms/step
# Epoch 211/1000
# 474/474 - 1s - loss: 22.2130 - val_loss: 21.4684 - 934ms/epoch - 2ms/step
# Epoch 212/1000
# 474/474 - 1s - loss: 22.6858 - val_loss: 24.7668 - 910ms/epoch - 2ms/step
# Epoch 213/1000
# 474/474 - 1s - loss: 22.4873 - val_loss: 22.3273 - 898ms/epoch - 2ms/step
# Epoch 214/1000
# 474/474 - 1s - loss: 23.7877 - val_loss: 22.3323 - 998ms/epoch - 2ms/step
# Epoch 215/1000
# 474/474 - 1s - loss: 21.3124 - val_loss: 20.6104 - 897ms/epoch - 2ms/step
# Epoch 216/1000
# 474/474 - 1s - loss: 22.9844 - val_loss: 20.2979 - 973ms/epoch - 2ms/step
# Epoch 217/1000
# 474/474 - 1s - loss: 23.2039 - val_loss: 20.6222 - 985ms/epoch - 2ms/step
# Epoch 218/1000
# 474/474 - 1s - loss: 21.8599 - val_loss: 18.3397 - 993ms/epoch - 2ms/step
# Epoch 219/1000
# 474/474 - 1s - loss: 22.2569 - val_loss: 21.2743 - 914ms/epoch - 2ms/step
# Epoch 220/1000
# 474/474 - 1s - loss: 22.6580 - val_loss: 30.5088 - 899ms/epoch - 2ms/step
# Epoch 221/1000
# 474/474 - 1s - loss: 24.3200 - val_loss: 22.4929 - 992ms/epoch - 2ms/step
# Epoch 222/1000
# 474/474 - 1s - loss: 21.0800 - val_loss: 19.7528 - 972ms/epoch - 2ms/step
# Epoch 223/1000
# 474/474 - 1s - loss: 22.8074 - val_loss: 23.1552 - 999ms/epoch - 2ms/step
# Epoch 224/1000
# 474/474 - 1s - loss: 20.6874 - val_loss: 22.2347 - 927ms/epoch - 2ms/step
# Epoch 225/1000
# 474/474 - 1s - loss: 21.2397 - val_loss: 27.4807 - 901ms/epoch - 2ms/step
# Epoch 226/1000
# 474/474 - 1s - loss: 20.8629 - val_loss: 22.8952 - 986ms/epoch - 2ms/step
# Epoch 227/1000
# 474/474 - 1s - loss: 20.7456 - val_loss: 22.3127 - 999ms/epoch - 2ms/step
# Epoch 228/1000
# 474/474 - 1s - loss: 18.9631 - val_loss: 27.7723 - 879ms/epoch - 2ms/step
# Epoch 229/1000
# 474/474 - 1s - loss: 21.2659 - val_loss: 33.0854 - 921ms/epoch - 2ms/step
# Epoch 230/1000
# 474/474 - 1s - loss: 19.7565 - val_loss: 21.4890 - 902ms/epoch - 2ms/step
# Epoch 231/1000
# 474/474 - 1s - loss: 21.5351 - val_loss: 20.8094 - 1s/epoch - 2ms/step
# Epoch 232/1000
# 474/474 - 1s - loss: 19.2493 - val_loss: 18.6454 - 921ms/epoch - 2ms/step
# Epoch 233/1000
# 474/474 - 1s - loss: 20.7602 - val_loss: 14.8377 - 982ms/epoch - 2ms/step
# Epoch 234/1000
# 474/474 - 1s - loss: 21.0854 - val_loss: 19.1840 - 919ms/epoch - 2ms/step
# Epoch 235/1000
# 474/474 - 1s - loss: 21.5065 - val_loss: 18.8044 - 909ms/epoch - 2ms/step
# Epoch 236/1000
# 474/474 - 1s - loss: 18.6446 - val_loss: 27.4129 - 975ms/epoch - 2ms/step
# Epoch 237/1000
# 474/474 - 1s - loss: 20.9704 - val_loss: 16.8267 - 994ms/epoch - 2ms/step
# Epoch 238/1000
# 474/474 - 1s - loss: 20.3391 - val_loss: 25.4944 - 900ms/epoch - 2ms/step
# Epoch 239/1000
# 474/474 - 1s - loss: 17.9231 - val_loss: 18.4379 - 900ms/epoch - 2ms/step
# Epoch 240/1000
# 474/474 - 1s - loss: 21.0571 - val_loss: 19.8314 - 988ms/epoch - 2ms/step
# Epoch 241/1000
# 474/474 - 1s - loss: 18.5894 - val_loss: 31.4104 - 897ms/epoch - 2ms/step
# Epoch 242/1000
# 474/474 - 1s - loss: 21.6345 - val_loss: 13.8168 - 911ms/epoch - 2ms/step
# Epoch 243/1000
# 474/474 - 1s - loss: 18.6470 - val_loss: 12.7341 - 1s/epoch - 2ms/step
# Epoch 244/1000
# 474/474 - 1s - loss: 19.6168 - val_loss: 16.5890 - 931ms/epoch - 2ms/step
# Epoch 245/1000
# 474/474 - 1s - loss: 18.5977 - val_loss: 19.2729 - 947ms/epoch - 2ms/step
# Epoch 246/1000
# 474/474 - 1s - loss: 18.6300 - val_loss: 15.6742 - 939ms/epoch - 2ms/step
# Epoch 247/1000
# 474/474 - 1s - loss: 16.3710 - val_loss: 13.7139 - 992ms/epoch - 2ms/step
# Epoch 248/1000
# 474/474 - 1s - loss: 17.5383 - val_loss: 23.3784 - 918ms/epoch - 2ms/step
# Epoch 249/1000
# 474/474 - 1s - loss: 17.0756 - val_loss: 17.5976 - 921ms/epoch - 2ms/step
# Epoch 250/1000
# 474/474 - 1s - loss: 20.3601 - val_loss: 38.6622 - 916ms/epoch - 2ms/step
# Epoch 251/1000
# 474/474 - 1s - loss: 20.6162 - val_loss: 16.1089 - 946ms/epoch - 2ms/step
# Epoch 252/1000
# 474/474 - 1s - loss: 18.4020 - val_loss: 20.4717 - 899ms/epoch - 2ms/step
# Epoch 253/1000
# 474/474 - 1s - loss: 17.8561 - val_loss: 13.4474 - 899ms/epoch - 2ms/step
# Epoch 254/1000
# 474/474 - 1s - loss: 17.4083 - val_loss: 13.5205 - 906ms/epoch - 2ms/step
# Epoch 255/1000
# 474/474 - 1s - loss: 16.1231 - val_loss: 14.7040 - 987ms/epoch - 2ms/step
# Epoch 256/1000
# 474/474 - 1s - loss: 17.0076 - val_loss: 12.6393 - 914ms/epoch - 2ms/step
# Epoch 257/1000
# 474/474 - 1s - loss: 16.2000 - val_loss: 19.5584 - 985ms/epoch - 2ms/step
# Epoch 258/1000
# 474/474 - 1s - loss: 14.2340 - val_loss: 41.3276 - 983ms/epoch - 2ms/step
# Epoch 259/1000
# 474/474 - 1s - loss: 15.1136 - val_loss: 13.8183 - 1s/epoch - 2ms/step
# Epoch 260/1000
# 474/474 - 1s - loss: 13.2949 - val_loss: 11.8121 - 926ms/epoch - 2ms/step
# Epoch 261/1000
# 474/474 - 1s - loss: 13.8943 - val_loss: 21.9119 - 941ms/epoch - 2ms/step
# Epoch 262/1000
# 474/474 - 1s - loss: 15.7670 - val_loss: 31.5756 - 1s/epoch - 2ms/step
# Epoch 263/1000
# 474/474 - 1s - loss: 15.2379 - val_loss: 18.1831 - 914ms/epoch - 2ms/step
# Epoch 264/1000
# 474/474 - 1s - loss: 14.4227 - val_loss: 16.6211 - 988ms/epoch - 2ms/step
# Epoch 265/1000
# 474/474 - 1s - loss: 14.8913 - val_loss: 11.7147 - 906ms/epoch - 2ms/step
# Epoch 266/1000
# 474/474 - 1s - loss: 16.2115 - val_loss: 9.8181 - 906ms/epoch - 2ms/step
# Epoch 267/1000
# 474/474 - 1s - loss: 14.6356 - val_loss: 16.1936 - 1s/epoch - 2ms/step
# Epoch 268/1000
# 474/474 - 1s - loss: 15.6600 - val_loss: 10.0497 - 982ms/epoch - 2ms/step
# Epoch 269/1000
# 474/474 - 1s - loss: 11.6969 - val_loss: 10.4915 - 921ms/epoch - 2ms/step
# Epoch 270/1000
# 474/474 - 1s - loss: 14.8724 - val_loss: 41.4165 - 922ms/epoch - 2ms/step
# Epoch 271/1000
# 474/474 - 1s - loss: 13.9004 - val_loss: 11.1163 - 998ms/epoch - 2ms/step
# Epoch 272/1000
# 474/474 - 1s - loss: 13.2856 - val_loss: 8.6110 - 898ms/epoch - 2ms/step
# Epoch 273/1000
# 474/474 - 1s - loss: 14.2696 - val_loss: 21.7733 - 1000ms/epoch - 2ms/step
# Epoch 274/1000
# 474/474 - 1s - loss: 12.8171 - val_loss: 9.2716 - 913ms/epoch - 2ms/step
# Epoch 275/1000
# 474/474 - 1s - loss: 12.6628 - val_loss: 15.7565 - 900ms/epoch - 2ms/step
# Epoch 276/1000
# 474/474 - 1s - loss: 11.2455 - val_loss: 7.2519 - 1s/epoch - 2ms/step
# Epoch 277/1000
# 474/474 - 1s - loss: 15.4662 - val_loss: 12.8343 - 919ms/epoch - 2ms/step
# Epoch 278/1000
# 474/474 - 1s - loss: 13.9385 - val_loss: 20.0257 - 921ms/epoch - 2ms/step
# Epoch 279/1000
# 474/474 - 1s - loss: 14.1276 - val_loss: 9.9910 - 896ms/epoch - 2ms/step
# Epoch 280/1000
# 474/474 - 1s - loss: 10.6264 - val_loss: 32.2787 - 919ms/epoch - 2ms/step
# Epoch 281/1000
# 474/474 - 1s - loss: 12.0651 - val_loss: 9.4711 - 997ms/epoch - 2ms/step
# Epoch 282/1000
# 474/474 - 1s - loss: 11.1219 - val_loss: 11.9733 - 998ms/epoch - 2ms/step
# Epoch 283/1000
# 474/474 - 1s - loss: 11.7504 - val_loss: 14.4724 - 993ms/epoch - 2ms/step
# Epoch 284/1000
# 474/474 - 1s - loss: 13.4746 - val_loss: 8.4572 - 980ms/epoch - 2ms/step
# Epoch 285/1000
# 474/474 - 1s - loss: 14.5996 - val_loss: 9.8923 - 1s/epoch - 2ms/step
# Epoch 286/1000
# 474/474 - 1s - loss: 9.6479 - val_loss: 7.9312 - 903ms/epoch - 2ms/step
# Epoch 287/1000
# 474/474 - 1s - loss: 12.6240 - val_loss: 14.2307 - 984ms/epoch - 2ms/step
# Epoch 288/1000
# 474/474 - 1s - loss: 13.8294 - val_loss: 11.7202 - 892ms/epoch - 2ms/step
# Epoch 289/1000
# 474/474 - 1s - loss: 10.4066 - val_loss: 8.5783 - 1s/epoch - 2ms/step
# Epoch 290/1000
# 474/474 - 1s - loss: 12.6568 - val_loss: 13.7453 - 915ms/epoch - 2ms/step
# Epoch 291/1000
# 474/474 - 1s - loss: 15.9433 - val_loss: 39.3514 - 906ms/epoch - 2ms/step
# Epoch 292/1000
# 474/474 - 1s - loss: 23.3737 - val_loss: 11.8567 - 1s/epoch - 2ms/step
# Epoch 293/1000
# 474/474 - 1s - loss: 10.9094 - val_loss: 18.0171 - 923ms/epoch - 2ms/step
# Epoch 294/1000
# 474/474 - 1s - loss: 16.9560 - val_loss: 26.2543 - 910ms/epoch - 2ms/step
# Epoch 295/1000
# 474/474 - 1s - loss: 12.7314 - val_loss: 11.3694 - 999ms/epoch - 2ms/step
# Epoch 296/1000
# 474/474 - 1s - loss: 12.2177 - val_loss: 11.4116 - 936ms/epoch - 2ms/step
# Epoch 297/1000
# 474/474 - 1s - loss: 13.0609 - val_loss: 15.0092 - 996ms/epoch - 2ms/step
# Epoch 298/1000
# 474/474 - 1s - loss: 12.3695 - val_loss: 8.6929 - 920ms/epoch - 2ms/step
# Epoch 299/1000
# 474/474 - 1s - loss: 11.6385 - val_loss: 8.3040 - 899ms/epoch - 2ms/step
# Epoch 300/1000
# 474/474 - 1s - loss: 11.0652 - val_loss: 7.1716 - 919ms/epoch - 2ms/step
# Epoch 301/1000
# 474/474 - 1s - loss: 10.9154 - val_loss: 22.7570 - 907ms/epoch - 2ms/step
# Epoch 302/1000
# 474/474 - 1s - loss: 10.5773 - val_loss: 12.4710 - 908ms/epoch - 2ms/step
# Epoch 303/1000
# 474/474 - 1s - loss: 10.8044 - val_loss: 10.3449 - 988ms/epoch - 2ms/step
# Epoch 304/1000
# 474/474 - 1s - loss: 9.8761 - val_loss: 6.6309 - 1s/epoch - 2ms/step
# Epoch 305/1000
# 474/474 - 1s - loss: 10.4773 - val_loss: 6.2673 - 918ms/epoch - 2ms/step
# Epoch 306/1000
# 474/474 - 1s - loss: 13.7753 - val_loss: 10.2309 - 998ms/epoch - 2ms/step
# Epoch 307/1000
# 474/474 - 1s - loss: 8.3995 - val_loss: 6.2371 - 1s/epoch - 2ms/step
# Epoch 308/1000
# 474/474 - 1s - loss: 11.1161 - val_loss: 9.9760 - 938ms/epoch - 2ms/step
# Epoch 309/1000
# 474/474 - 1s - loss: 8.5120 - val_loss: 6.7777 - 914ms/epoch - 2ms/step
# Epoch 310/1000
# 474/474 - 1s - loss: 10.6210 - val_loss: 31.1061 - 892ms/epoch - 2ms/step
# Epoch 311/1000
# 474/474 - 1s - loss: 11.3554 - val_loss: 13.1398 - 916ms/epoch - 2ms/step
# Epoch 312/1000
# 474/474 - 1s - loss: 8.9931 - val_loss: 7.9840 - 914ms/epoch - 2ms/step
# Epoch 313/1000
# 474/474 - 1s - loss: 10.3903 - val_loss: 8.8945 - 931ms/epoch - 2ms/step
# Epoch 314/1000
# 474/474 - 1s - loss: 9.4693 - val_loss: 8.4183 - 998ms/epoch - 2ms/step
# Epoch 315/1000
# 474/474 - 1s - loss: 10.9246 - val_loss: 6.4879 - 901ms/epoch - 2ms/step
# Epoch 316/1000
# 474/474 - 1s - loss: 10.0910 - val_loss: 11.5854 - 903ms/epoch - 2ms/step
# Epoch 317/1000
# 474/474 - 1s - loss: 8.7857 - val_loss: 11.2740 - 984ms/epoch - 2ms/step
# Epoch 318/1000
# 474/474 - 1s - loss: 10.4226 - val_loss: 5.3046 - 939ms/epoch - 2ms/step
# Epoch 319/1000
# 474/474 - 1s - loss: 10.0219 - val_loss: 6.7385 - 896ms/epoch - 2ms/step
# Epoch 320/1000
# 474/474 - 1s - loss: 8.3306 - val_loss: 5.2016 - 989ms/epoch - 2ms/step
# Epoch 321/1000
# 474/474 - 1s - loss: 11.1388 - val_loss: 7.1553 - 900ms/epoch - 2ms/step
# Epoch 322/1000
# 474/474 - 1s - loss: 10.2785 - val_loss: 21.2359 - 984ms/epoch - 2ms/step
# Epoch 323/1000
# 474/474 - 1s - loss: 10.6341 - val_loss: 5.9507 - 904ms/epoch - 2ms/step
# Epoch 324/1000
# 474/474 - 1s - loss: 9.4677 - val_loss: 46.9737 - 1s/epoch - 2ms/step
# Epoch 325/1000
# 474/474 - 1s - loss: 9.1264 - val_loss: 6.8879 - 911ms/epoch - 2ms/step
# Epoch 326/1000
# 474/474 - 1s - loss: 9.8159 - val_loss: 5.3560 - 926ms/epoch - 2ms/step
# Epoch 327/1000
# 474/474 - 1s - loss: 8.1704 - val_loss: 12.2879 - 999ms/epoch - 2ms/step
# Epoch 328/1000
# 474/474 - 1s - loss: 9.0001 - val_loss: 10.0610 - 977ms/epoch - 2ms/step
# Epoch 329/1000
# 474/474 - 1s - loss: 9.2526 - val_loss: 5.7225 - 936ms/epoch - 2ms/step
# Epoch 330/1000
# 474/474 - 1s - loss: 8.1192 - val_loss: 7.5241 - 921ms/epoch - 2ms/step
# Epoch 331/1000
# 474/474 - 1s - loss: 8.0113 - val_loss: 10.4208 - 889ms/epoch - 2ms/step
# Epoch 332/1000
# 474/474 - 1s - loss: 9.2226 - val_loss: 5.1763 - 922ms/epoch - 2ms/step
# Epoch 333/1000
# 474/474 - 1s - loss: 16.1488 - val_loss: 30.8499 - 921ms/epoch - 2ms/step
# Epoch 334/1000
# 474/474 - 1s - loss: 11.4274 - val_loss: 8.6305 - 925ms/epoch - 2ms/step
# Epoch 335/1000
# 474/474 - 1s - loss: 8.9125 - val_loss: 10.0694 - 917ms/epoch - 2ms/step
# Epoch 336/1000
# 474/474 - 1s - loss: 8.9171 - val_loss: 4.9985 - 898ms/epoch - 2ms/step
# Epoch 337/1000
# 474/474 - 1s - loss: 6.4332 - val_loss: 5.3985 - 902ms/epoch - 2ms/step
# Epoch 338/1000
# 474/474 - 1s - loss: 7.2354 - val_loss: 6.7095 - 917ms/epoch - 2ms/step
# Epoch 339/1000
# 474/474 - 1s - loss: 10.9993 - val_loss: 8.9485 - 907ms/epoch - 2ms/step
# Epoch 340/1000
# 474/474 - 1s - loss: 8.6259 - val_loss: 5.2490 - 990ms/epoch - 2ms/step
# Epoch 341/1000
# 474/474 - 1s - loss: 6.5814 - val_loss: 14.0439 - 947ms/epoch - 2ms/step
# Epoch 342/1000
# 474/474 - 1s - loss: 9.9080 - val_loss: 23.0708 - 920ms/epoch - 2ms/step
# Epoch 343/1000
# 474/474 - 1s - loss: 7.9832 - val_loss: 7.1168 - 898ms/epoch - 2ms/step
# Epoch 344/1000
# 474/474 - 1s - loss: 8.0002 - val_loss: 6.4164 - 912ms/epoch - 2ms/step
# Epoch 345/1000
# 474/474 - 1s - loss: 8.8705 - val_loss: 13.6094 - 985ms/epoch - 2ms/step
# Epoch 346/1000
# 474/474 - 1s - loss: 8.8579 - val_loss: 9.9638 - 922ms/epoch - 2ms/step
# Epoch 347/1000
# 474/474 - 1s - loss: 8.1092 - val_loss: 4.7252 - 910ms/epoch - 2ms/step
# Epoch 348/1000
# 474/474 - 1s - loss: 7.0510 - val_loss: 5.6580 - 907ms/epoch - 2ms/step
# Epoch 349/1000
# 474/474 - 1s - loss: 7.4820 - val_loss: 9.6069 - 914ms/epoch - 2ms/step
# Epoch 350/1000
# 474/474 - 1s - loss: 8.3900 - val_loss: 4.8435 - 913ms/epoch - 2ms/step
# Epoch 351/1000
# 474/474 - 1s - loss: 8.2896 - val_loss: 8.2839 - 914ms/epoch - 2ms/step
# Epoch 352/1000
# 474/474 - 1s - loss: 8.5260 - val_loss: 4.4098 - 974ms/epoch - 2ms/step
# Epoch 353/1000
# 474/474 - 1s - loss: 8.5569 - val_loss: 10.6134 - 931ms/epoch - 2ms/step
# Epoch 354/1000
# 474/474 - 1s - loss: 8.3966 - val_loss: 10.9233 - 1s/epoch - 2ms/step
# Epoch 355/1000
# 474/474 - 1s - loss: 8.1169 - val_loss: 6.4790 - 890ms/epoch - 2ms/step
# Epoch 356/1000
# 474/474 - 1s - loss: 7.4825 - val_loss: 4.7105 - 982ms/epoch - 2ms/step
# Epoch 357/1000
# 474/474 - 1s - loss: 11.2717 - val_loss: 5.9705 - 907ms/epoch - 2ms/step
# Epoch 358/1000
# 474/474 - 1s - loss: 9.2951 - val_loss: 7.7673 - 906ms/epoch - 2ms/step
# Epoch 359/1000
# 474/474 - 1s - loss: 7.2060 - val_loss: 5.7083 - 904ms/epoch - 2ms/step
# Epoch 360/1000
# 474/474 - 1s - loss: 8.0210 - val_loss: 5.9868 - 912ms/epoch - 2ms/step
# Epoch 361/1000
# 474/474 - 1s - loss: 7.4892 - val_loss: 6.5783 - 995ms/epoch - 2ms/step
# Epoch 362/1000
# 474/474 - 1s - loss: 8.0796 - val_loss: 13.7956 - 984ms/epoch - 2ms/step
# Epoch 363/1000
# 474/474 - 1s - loss: 9.3100 - val_loss: 12.7235 - 975ms/epoch - 2ms/step
# Epoch 364/1000
# 474/474 - 1s - loss: 7.5207 - val_loss: 7.0149 - 897ms/epoch - 2ms/step
# Epoch 365/1000
# 474/474 - 1s - loss: 7.1564 - val_loss: 8.0511 - 974ms/epoch - 2ms/step
# Epoch 366/1000
# 474/474 - 1s - loss: 6.8979 - val_loss: 22.5247 - 893ms/epoch - 2ms/step
# Epoch 367/1000
# 474/474 - 1s - loss: 6.8496 - val_loss: 4.5638 - 905ms/epoch - 2ms/step
# Epoch 368/1000
# 474/474 - 1s - loss: 8.9863 - val_loss: 5.3266 - 882ms/epoch - 2ms/step
# Epoch 369/1000
# 474/474 - 1s - loss: 8.5644 - val_loss: 11.5551 - 900ms/epoch - 2ms/step
# Epoch 370/1000
# 474/474 - 1s - loss: 7.8200 - val_loss: 6.1231 - 981ms/epoch - 2ms/step
# Epoch 371/1000
# 474/474 - 1s - loss: 6.9540 - val_loss: 4.2998 - 923ms/epoch - 2ms/step
# Epoch 372/1000
# 474/474 - 1s - loss: 8.0385 - val_loss: 5.1283 - 1s/epoch - 2ms/step
# Epoch 373/1000
# 474/474 - 1s - loss: 6.6473 - val_loss: 7.1980 - 899ms/epoch - 2ms/step
# Epoch 374/1000
# 474/474 - 1s - loss: 8.7065 - val_loss: 18.1195 - 991ms/epoch - 2ms/step
# Epoch 375/1000
# 474/474 - 1s - loss: 8.0479 - val_loss: 11.1702 - 993ms/epoch - 2ms/step
# Epoch 376/1000
# 474/474 - 1s - loss: 7.1370 - val_loss: 8.3912 - 920ms/epoch - 2ms/step
# Epoch 377/1000
# 474/474 - 1s - loss: 7.7696 - val_loss: 6.6896 - 981ms/epoch - 2ms/step
# Epoch 378/1000
# 474/474 - 1s - loss: 6.8566 - val_loss: 6.3238 - 907ms/epoch - 2ms/step
# Epoch 379/1000
# 474/474 - 1s - loss: 5.4677 - val_loss: 8.5376 - 1s/epoch - 2ms/step
# Epoch 380/1000
# 474/474 - 1s - loss: 6.4027 - val_loss: 10.0551 - 990ms/epoch - 2ms/step
# Epoch 381/1000
# 474/474 - 1s - loss: 8.5806 - val_loss: 7.5718 - 922ms/epoch - 2ms/step
# Epoch 382/1000
# 474/474 - 1s - loss: 8.0036 - val_loss: 20.9154 - 902ms/epoch - 2ms/step
# Epoch 383/1000
# 474/474 - 1s - loss: 8.0608 - val_loss: 5.6884 - 902ms/epoch - 2ms/step
# Epoch 384/1000
# 474/474 - 1s - loss: 6.9782 - val_loss: 5.4539 - 976ms/epoch - 2ms/step
# Epoch 385/1000
# 474/474 - 1s - loss: 7.4561 - val_loss: 64.9263 - 922ms/epoch - 2ms/step
# Epoch 386/1000
# 474/474 - 1s - loss: 8.8200 - val_loss: 12.7781 - 916ms/epoch - 2ms/step
# Epoch 387/1000
# 474/474 - 1s - loss: 7.9214 - val_loss: 6.9260 - 926ms/epoch - 2ms/step
# Epoch 388/1000
# 474/474 - 1s - loss: 6.5060 - val_loss: 18.1072 - 984ms/epoch - 2ms/step
# Epoch 389/1000
# 474/474 - 1s - loss: 6.6747 - val_loss: 14.5350 - 944ms/epoch - 2ms/step
# Epoch 390/1000
# 474/474 - 1s - loss: 6.8206 - val_loss: 8.3391 - 921ms/epoch - 2ms/step
# Epoch 391/1000
# 474/474 - 1s - loss: 8.1808 - val_loss: 15.5511 - 979ms/epoch - 2ms/step
# Epoch 392/1000
# 474/474 - 1s - loss: 7.6087 - val_loss: 16.6056 - 930ms/epoch - 2ms/step
# Epoch 393/1000
# 474/474 - 1s - loss: 6.8625 - val_loss: 7.0145 - 990ms/epoch - 2ms/step
# Epoch 394/1000
# 474/474 - 1s - loss: 6.7522 - val_loss: 5.6610 - 909ms/epoch - 2ms/step
# Epoch 395/1000
# 474/474 - 1s - loss: 6.3308 - val_loss: 8.6674 - 986ms/epoch - 2ms/step
# Epoch 396/1000
# 474/474 - 1s - loss: 6.4035 - val_loss: 5.3958 - 914ms/epoch - 2ms/step
# Epoch 397/1000
# 474/474 - 1s - loss: 6.0605 - val_loss: 7.0194 - 929ms/epoch - 2ms/step
# Epoch 398/1000
# 474/474 - 1s - loss: 5.7124 - val_loss: 5.0656 - 920ms/epoch - 2ms/step
# Epoch 399/1000
# 474/474 - 1s - loss: 6.1825 - val_loss: 4.7312 - 973ms/epoch - 2ms/step
# Epoch 400/1000
# 474/474 - 1s - loss: 7.5573 - val_loss: 26.1361 - 905ms/epoch - 2ms/step
# Epoch 401/1000
# 474/474 - 1s - loss: 6.8752 - val_loss: 9.3362 - 989ms/epoch - 2ms/step
# Epoch 402/1000
# 474/474 - 1s - loss: 6.0857 - val_loss: 3.7523 - 913ms/epoch - 2ms/step
# Epoch 403/1000
# 474/474 - 1s - loss: 5.8543 - val_loss: 4.7580 - 890ms/epoch - 2ms/step
# Epoch 404/1000
# 474/474 - 1s - loss: 8.1860 - val_loss: 4.1064 - 1000ms/epoch - 2ms/step
# Epoch 405/1000
# 474/474 - 1s - loss: 18.4649 - val_loss: 11.6900 - 916ms/epoch - 2ms/step
# Epoch 406/1000
# 474/474 - 1s - loss: 8.7968 - val_loss: 11.7363 - 991ms/epoch - 2ms/step
# Epoch 407/1000
# 474/474 - 1s - loss: 6.9145 - val_loss: 4.8012 - 1s/epoch - 2ms/step
# Epoch 408/1000
# 474/474 - 1s - loss: 8.4341 - val_loss: 6.7095 - 910ms/epoch - 2ms/step
# Epoch 409/1000
# 474/474 - 1s - loss: 6.6120 - val_loss: 5.3168 - 943ms/epoch - 2ms/step
# Epoch 410/1000
# 474/474 - 1s - loss: 6.8723 - val_loss: 7.6219 - 922ms/epoch - 2ms/step
# Epoch 411/1000
# 474/474 - 1s - loss: 6.8773 - val_loss: 4.4054 - 909ms/epoch - 2ms/step
# Epoch 412/1000
# 474/474 - 1s - loss: 7.8082 - val_loss: 4.1300 - 889ms/epoch - 2ms/step
# Epoch 413/1000
# 474/474 - 1s - loss: 7.9312 - val_loss: 23.7617 - 945ms/epoch - 2ms/step
# Epoch 414/1000
# 474/474 - 1s - loss: 7.1481 - val_loss: 4.0839 - 901ms/epoch - 2ms/step
# Epoch 415/1000
# 474/474 - 1s - loss: 6.1184 - val_loss: 5.9064 - 907ms/epoch - 2ms/step
# Epoch 416/1000
# 474/474 - 1s - loss: 5.9836 - val_loss: 4.8575 - 973ms/epoch - 2ms/step
# Epoch 417/1000
# 474/474 - 1s - loss: 8.5490 - val_loss: 6.9558 - 1s/epoch - 2ms/step
# Epoch 418/1000
# 474/474 - 1s - loss: 7.9830 - val_loss: 11.5713 - 920ms/epoch - 2ms/step
# Epoch 419/1000
# 474/474 - 1s - loss: 6.9613 - val_loss: 4.2355 - 939ms/epoch - 2ms/step
# Epoch 420/1000
# 474/474 - 1s - loss: 5.4564 - val_loss: 4.0888 - 925ms/epoch - 2ms/step
# Epoch 421/1000
# 474/474 - 1s - loss: 6.1314 - val_loss: 10.7565 - 937ms/epoch - 2ms/step
# Epoch 422/1000
# 474/474 - 1s - loss: 5.4580 - val_loss: 6.1550 - 922ms/epoch - 2ms/step
# Epoch 423/1000
# 474/474 - 1s - loss: 7.7025 - val_loss: 4.5493 - 1s/epoch - 2ms/step
# Epoch 424/1000
# 474/474 - 1s - loss: 6.6912 - val_loss: 7.0955 - 898ms/epoch - 2ms/step
# Epoch 425/1000
# 474/474 - 1s - loss: 5.8283 - val_loss: 6.8277 - 967ms/epoch - 2ms/step
# Epoch 426/1000
# 474/474 - 1s - loss: 6.2184 - val_loss: 3.5763 - 921ms/epoch - 2ms/step
# Epoch 427/1000
# 474/474 - 1s - loss: 7.0863 - val_loss: 10.0899 - 919ms/epoch - 2ms/step
# Epoch 428/1000
# 474/474 - 1s - loss: 6.2467 - val_loss: 4.2067 - 906ms/epoch - 2ms/step
# Epoch 429/1000
# 474/474 - 1s - loss: 5.2538 - val_loss: 3.9407 - 1s/epoch - 2ms/step
# Epoch 430/1000
# 474/474 - 1s - loss: 6.2577 - val_loss: 25.7166 - 913ms/epoch - 2ms/step
# Epoch 431/1000
# 474/474 - 1s - loss: 7.8518 - val_loss: 7.2007 - 922ms/epoch - 2ms/step
# Epoch 432/1000
# 474/474 - 1s - loss: 5.7723 - val_loss: 8.6397 - 936ms/epoch - 2ms/step
# Epoch 433/1000
# 474/474 - 1s - loss: 7.4803 - val_loss: 5.5791 - 913ms/epoch - 2ms/step
# Epoch 434/1000
# 474/474 - 1s - loss: 6.7214 - val_loss: 4.3119 - 941ms/epoch - 2ms/step
# Epoch 435/1000
# 474/474 - 1s - loss: 7.5575 - val_loss: 10.4640 - 989ms/epoch - 2ms/step
# Epoch 436/1000
# 474/474 - 1s - loss: 6.0389 - val_loss: 3.4592 - 1s/epoch - 2ms/step
# Epoch 437/1000
# 474/474 - 1s - loss: 5.4386 - val_loss: 3.7174 - 923ms/epoch - 2ms/step
# Epoch 438/1000
# 474/474 - 1s - loss: 5.1793 - val_loss: 5.0296 - 904ms/epoch - 2ms/step
# Epoch 439/1000
# 474/474 - 1s - loss: 5.9173 - val_loss: 10.5978 - 971ms/epoch - 2ms/step
# Epoch 440/1000
# 474/474 - 1s - loss: 6.0427 - val_loss: 8.5718 - 975ms/epoch - 2ms/step
# Epoch 441/1000
# 474/474 - 1s - loss: 6.3862 - val_loss: 3.4473 - 904ms/epoch - 2ms/step
# Epoch 442/1000
# 474/474 - 1s - loss: 5.4710 - val_loss: 4.2627 - 995ms/epoch - 2ms/step
# Epoch 443/1000
# 474/474 - 1s - loss: 5.8162 - val_loss: 4.3458 - 1s/epoch - 2ms/step
# Epoch 444/1000
# 474/474 - 1s - loss: 4.7379 - val_loss: 5.2922 - 989ms/epoch - 2ms/step
# Epoch 445/1000
# 474/474 - 1s - loss: 5.8076 - val_loss: 11.5622 - 922ms/epoch - 2ms/step
# Epoch 446/1000
# 474/474 - 1s - loss: 5.4990 - val_loss: 5.3569 - 997ms/epoch - 2ms/step
# Epoch 447/1000
# 474/474 - 1s - loss: 5.9631 - val_loss: 11.0269 - 908ms/epoch - 2ms/step
# Epoch 448/1000
# 474/474 - 1s - loss: 6.2025 - val_loss: 7.0301 - 994ms/epoch - 2ms/step
# Epoch 449/1000
# 474/474 - 1s - loss: 5.6706 - val_loss: 3.8759 - 922ms/epoch - 2ms/step
# Epoch 450/1000
# 474/474 - 1s - loss: 4.9157 - val_loss: 5.8409 - 997ms/epoch - 2ms/step
# Epoch 451/1000
# 474/474 - 1s - loss: 7.1890 - val_loss: 5.4038 - 931ms/epoch - 2ms/step
# Epoch 452/1000
# 474/474 - 1s - loss: 5.3918 - val_loss: 3.5856 - 927ms/epoch - 2ms/step
# Epoch 453/1000
# 474/474 - 1s - loss: 5.4537 - val_loss: 5.1399 - 908ms/epoch - 2ms/step
# Epoch 454/1000
# 474/474 - 1s - loss: 4.9382 - val_loss: 6.4325 - 939ms/epoch - 2ms/step
# Epoch 455/1000
# 474/474 - 1s - loss: 6.4455 - val_loss: 4.8066 - 915ms/epoch - 2ms/step
# Epoch 456/1000
# 474/474 - 1s - loss: 8.1229 - val_loss: 26.6352 - 898ms/epoch - 2ms/step
# Epoch 457/1000
# 474/474 - 1s - loss: 7.6403 - val_loss: 6.6032 - 976ms/epoch - 2ms/step
# Epoch 458/1000
# 474/474 - 1s - loss: 5.7250 - val_loss: 4.4383 - 903ms/epoch - 2ms/step
# Epoch 459/1000
# 474/474 - 1s - loss: 5.0080 - val_loss: 3.4495 - 911ms/epoch - 2ms/step
# Epoch 460/1000
# 474/474 - 1s - loss: 4.5618 - val_loss: 5.1201 - 923ms/epoch - 2ms/step
# Epoch 461/1000
# 474/474 - 1s - loss: 5.3676 - val_loss: 4.2984 - 915ms/epoch - 2ms/step
# Epoch 462/1000
# 474/474 - 1s - loss: 4.6692 - val_loss: 4.3948 - 912ms/epoch - 2ms/step
# Epoch 463/1000
# 474/474 - 1s - loss: 5.6925 - val_loss: 7.9964 - 900ms/epoch - 2ms/step
# Epoch 464/1000
# 474/474 - 1s - loss: 8.9600 - val_loss: 9.3109 - 914ms/epoch - 2ms/step
# Epoch 465/1000
# 474/474 - 1s - loss: 6.0251 - val_loss: 4.9831 - 916ms/epoch - 2ms/step
# Epoch 466/1000
# 474/474 - 1s - loss: 4.6175 - val_loss: 4.1730 - 920ms/epoch - 2ms/step
# Epoch 467/1000
# 474/474 - 1s - loss: 5.4626 - val_loss: 6.7750 - 904ms/epoch - 2ms/step
# Epoch 468/1000
# 474/474 - 1s - loss: 6.2813 - val_loss: 10.4482 - 888ms/epoch - 2ms/step
# Epoch 469/1000
# 474/474 - 1s - loss: 4.8340 - val_loss: 3.5967 - 913ms/epoch - 2ms/step
# Epoch 470/1000
# 474/474 - 1s - loss: 5.4927 - val_loss: 3.9233 - 971ms/epoch - 2ms/step
# Epoch 471/1000
# 474/474 - 1s - loss: 5.2994 - val_loss: 3.7905 - 887ms/epoch - 2ms/step
# Epoch 472/1000
# 474/474 - 1s - loss: 6.9758 - val_loss: 5.6238 - 941ms/epoch - 2ms/step
# Epoch 473/1000
# 474/474 - 1s - loss: 6.4038 - val_loss: 6.6125 - 894ms/epoch - 2ms/step
# Epoch 474/1000
# 474/474 - 1s - loss: 6.4900 - val_loss: 3.9464 - 907ms/epoch - 2ms/step
# Epoch 475/1000
# 474/474 - 1s - loss: 5.6715 - val_loss: 5.3519 - 962ms/epoch - 2ms/step
# Epoch 476/1000
# 474/474 - 1s - loss: 6.5145 - val_loss: 8.3554 - 977ms/epoch - 2ms/step
# Epoch 477/1000
# 474/474 - 1s - loss: 5.0018 - val_loss: 5.0423 - 1s/epoch - 2ms/step
# Epoch 478/1000
# 474/474 - 1s - loss: 6.2553 - val_loss: 7.3801 - 900ms/epoch - 2ms/step
# Epoch 479/1000
# 474/474 - 1s - loss: 5.4405 - val_loss: 9.5331 - 878ms/epoch - 2ms/step
# Epoch 480/1000
# 474/474 - 1s - loss: 15.9081 - val_loss: 4.2834 - 902ms/epoch - 2ms/step
# Epoch 481/1000
# 474/474 - 1s - loss: 5.2413 - val_loss: 3.5143 - 935ms/epoch - 2ms/step
# Epoch 482/1000
# 474/474 - 1s - loss: 6.7704 - val_loss: 6.8666 - 910ms/epoch - 2ms/step
# Epoch 483/1000
# 474/474 - 1s - loss: 5.8298 - val_loss: 3.3632 - 992ms/epoch - 2ms/step
# Epoch 484/1000
# 474/474 - 1s - loss: 4.4214 - val_loss: 5.2407 - 923ms/epoch - 2ms/step
# Epoch 485/1000
# 474/474 - 1s - loss: 4.9429 - val_loss: 3.7722 - 899ms/epoch - 2ms/step
# Epoch 486/1000
# 474/474 - 1s - loss: 5.1369 - val_loss: 5.5231 - 922ms/epoch - 2ms/step
# Epoch 487/1000
# 474/474 - 1s - loss: 4.8845 - val_loss: 4.1010 - 939ms/epoch - 2ms/step
# Epoch 488/1000
# 474/474 - 1s - loss: 5.5515 - val_loss: 4.8416 - 1s/epoch - 2ms/step
# Epoch 489/1000
# 474/474 - 1s - loss: 5.1853 - val_loss: 3.5789 - 908ms/epoch - 2ms/step
# Epoch 490/1000
# 474/474 - 1s - loss: 4.6701 - val_loss: 5.0978 - 990ms/epoch - 2ms/step
# Epoch 491/1000
# 474/474 - 1s - loss: 5.7999 - val_loss: 3.4544 - 922ms/epoch - 2ms/step
# Epoch 492/1000
# 474/474 - 1s - loss: 4.7022 - val_loss: 3.4307 - 890ms/epoch - 2ms/step
# Epoch 493/1000
# 474/474 - 1s - loss: 4.9850 - val_loss: 10.4555 - 928ms/epoch - 2ms/step
# Epoch 494/1000
# 474/474 - 1s - loss: 5.3677 - val_loss: 7.6215 - 988ms/epoch - 2ms/step
# Epoch 495/1000
# 474/474 - 1s - loss: 6.0767 - val_loss: 4.2702 - 1s/epoch - 2ms/step
# Epoch 496/1000
# 474/474 - 1s - loss: 5.1235 - val_loss: 4.6477 - 939ms/epoch - 2ms/step
# Epoch 497/1000
# 474/474 - 1s - loss: 5.1181 - val_loss: 4.7658 - 921ms/epoch - 2ms/step
# Epoch 498/1000
# 474/474 - 1s - loss: 5.3689 - val_loss: 3.3606 - 938ms/epoch - 2ms/step
# Epoch 499/1000
# 474/474 - 1s - loss: 5.0032 - val_loss: 3.7337 - 913ms/epoch - 2ms/step
# Epoch 500/1000
# 474/474 - 1s - loss: 6.2444 - val_loss: 3.9275 - 938ms/epoch - 2ms/step
# Epoch 501/1000
# 474/474 - 1s - loss: 5.2297 - val_loss: 4.9502 - 888ms/epoch - 2ms/step
# Epoch 502/1000
# 474/474 - 1s - loss: 4.5605 - val_loss: 3.7648 - 888ms/epoch - 2ms/step
# Epoch 503/1000
# 474/474 - 1s - loss: 6.9355 - val_loss: 4.1751 - 981ms/epoch - 2ms/step
# Epoch 504/1000
# 474/474 - 1s - loss: 5.3796 - val_loss: 3.9466 - 972ms/epoch - 2ms/step
# Epoch 505/1000
# 474/474 - 1s - loss: 4.4287 - val_loss: 3.4059 - 901ms/epoch - 2ms/step
# Epoch 506/1000
# 474/474 - 1s - loss: 6.1801 - val_loss: 5.3181 - 927ms/epoch - 2ms/step
# Epoch 507/1000
# 474/474 - 1s - loss: 4.8771 - val_loss: 4.8647 - 910ms/epoch - 2ms/step
# Epoch 508/1000
# 474/474 - 1s - loss: 5.0776 - val_loss: 3.7554 - 934ms/epoch - 2ms/step
# Epoch 509/1000
# 474/474 - 1s - loss: 4.8994 - val_loss: 4.1558 - 899ms/epoch - 2ms/step
# Epoch 510/1000
# 474/474 - 1s - loss: 4.5793 - val_loss: 4.0698 - 902ms/epoch - 2ms/step
# Epoch 511/1000
# 474/474 - 1s - loss: 5.3972 - val_loss: 3.9299 - 912ms/epoch - 2ms/step
# Epoch 512/1000
# 474/474 - 1s - loss: 5.2788 - val_loss: 3.5647 - 902ms/epoch - 2ms/step
# Epoch 513/1000
# 474/474 - 1s - loss: 4.4605 - val_loss: 4.0171 - 902ms/epoch - 2ms/step
# Epoch 514/1000
# 474/474 - 1s - loss: 5.1517 - val_loss: 3.2312 - 915ms/epoch - 2ms/step
# Epoch 515/1000
# 474/474 - 1s - loss: 5.5815 - val_loss: 4.1380 - 883ms/epoch - 2ms/step
# Epoch 516/1000
# 474/474 - 1s - loss: 5.5543 - val_loss: 4.8578 - 937ms/epoch - 2ms/step
# Epoch 517/1000
# 474/474 - 1s - loss: 5.0958 - val_loss: 3.9592 - 1s/epoch - 2ms/step
# Epoch 518/1000
# 474/474 - 1s - loss: 5.0531 - val_loss: 4.3127 - 999ms/epoch - 2ms/step
# Epoch 519/1000
# 474/474 - 1s - loss: 5.6112 - val_loss: 3.8758 - 914ms/epoch - 2ms/step
# Epoch 520/1000
# 474/474 - 1s - loss: 4.1310 - val_loss: 3.3903 - 996ms/epoch - 2ms/step
# Epoch 521/1000
# 474/474 - 1s - loss: 5.6547 - val_loss: 3.7485 - 1s/epoch - 2ms/step
# Epoch 522/1000
# 474/474 - 1s - loss: 5.2441 - val_loss: 4.4448 - 986ms/epoch - 2ms/step
# Epoch 523/1000
# 474/474 - 1s - loss: 5.0818 - val_loss: 3.1184 - 920ms/epoch - 2ms/step
# Epoch 524/1000
# 474/474 - 1s - loss: 5.1986 - val_loss: 8.8044 - 926ms/epoch - 2ms/step
# Epoch 525/1000
# 474/474 - 1s - loss: 5.1793 - val_loss: 3.3626 - 1s/epoch - 2ms/step
# Epoch 526/1000
# 474/474 - 1s - loss: 4.3836 - val_loss: 4.4346 - 991ms/epoch - 2ms/step
# Epoch 527/1000
# 474/474 - 1s - loss: 4.9413 - val_loss: 4.4935 - 920ms/epoch - 2ms/step
# Epoch 528/1000
# 474/474 - 1s - loss: 4.4781 - val_loss: 3.5131 - 981ms/epoch - 2ms/step
# Epoch 529/1000
# 474/474 - 1s - loss: 5.4374 - val_loss: 3.8577 - 912ms/epoch - 2ms/step
# Epoch 530/1000
# 474/474 - 1s - loss: 5.0522 - val_loss: 9.4841 - 915ms/epoch - 2ms/step
# Epoch 531/1000
# 474/474 - 1s - loss: 5.1587 - val_loss: 4.3382 - 974ms/epoch - 2ms/step
# Epoch 532/1000
# 474/474 - 1s - loss: 5.4551 - val_loss: 6.3732 - 992ms/epoch - 2ms/step
# Epoch 533/1000
# 474/474 - 1s - loss: 5.8491 - val_loss: 3.6139 - 1s/epoch - 2ms/step
# Epoch 534/1000
# 474/474 - 1s - loss: 4.4200 - val_loss: 3.3508 - 972ms/epoch - 2ms/step
# Epoch 535/1000
# 474/474 - 1s - loss: 5.2819 - val_loss: 6.4621 - 963ms/epoch - 2ms/step
# Epoch 536/1000
# 474/474 - 1s - loss: 4.7765 - val_loss: 4.1905 - 921ms/epoch - 2ms/step
# Epoch 537/1000
# 474/474 - 1s - loss: 4.4098 - val_loss: 6.0099 - 978ms/epoch - 2ms/step
# Epoch 538/1000
# 474/474 - 1s - loss: 6.4663 - val_loss: 10.9686 - 988ms/epoch - 2ms/step
# Epoch 539/1000
# 474/474 - 1s - loss: 5.8094 - val_loss: 3.2891 - 918ms/epoch - 2ms/step
# Epoch 540/1000
# 474/474 - 1s - loss: 4.5681 - val_loss: 4.7036 - 986ms/epoch - 2ms/step
# Epoch 541/1000
# 474/474 - 1s - loss: 4.4683 - val_loss: 4.0410 - 905ms/epoch - 2ms/step
# Epoch 542/1000
# 474/474 - 1s - loss: 4.4349 - val_loss: 4.0707 - 1s/epoch - 2ms/step
# Epoch 543/1000
# 474/474 - 1s - loss: 5.7323 - val_loss: 21.5503 - 906ms/epoch - 2ms/step
# Epoch 544/1000
# 474/474 - 1s - loss: 5.9397 - val_loss: 3.2696 - 912ms/epoch - 2ms/step
# Epoch 545/1000
# 474/474 - 1s - loss: 4.2993 - val_loss: 4.5480 - 1s/epoch - 2ms/step
# Epoch 546/1000
# 474/474 - 1s - loss: 5.1823 - val_loss: 3.6264 - 981ms/epoch - 2ms/step
# Epoch 547/1000
# 474/474 - 1s - loss: 4.3237 - val_loss: 3.6927 - 918ms/epoch - 2ms/step
# ...
# Epoch 817/1000
# 474/474 - 1s - loss: 3.7692 - val_loss: 2.9158 - 927ms/epoch - 2ms/step
# Epoch 818/1000
# 474/474 - 1s - loss: 3.1302 - val_loss: 2.4326 - 898ms/epoch - 2ms/step
# Epoch 819/1000
# 474/474 - 1s - loss: 3.4019 - val_loss: 3.9493 - 898ms/epoch - 2ms/step
# Epoch 820/1000
# 474/474 - 1s - loss: 3.5927 - val_loss: 3.3746 - 995ms/epoch - 2ms/step
# Epoch 821/1000
# 474/474 - 1s - loss: 3.2458 - val_loss: 2.5561 - 911ms/epoch - 2ms/step
# Epoch 822/1000
# 474/474 - 1s - loss: 3.4254 - val_loss: 4.7381 - 903ms/epoch - 2ms/step
# Epoch 823/1000
# 474/474 - 1s - loss: 4.7855 - val_loss: 4.2061 - 915ms/epoch - 2ms/step
# Epoch 824/1000
# 474/474 - 1s - loss: 3.9943 - val_loss: 2.4063 - 1000ms/epoch - 2ms/step
# Epoch 825/1000
# 474/474 - 1s - loss: 3.4311 - val_loss: 2.7669 - 1s/epoch - 2ms/step
# Epoch 826/1000
# 474/474 - 1s - loss: 4.1220 - val_loss: 3.1826 - 914ms/epoch - 2ms/step
# Epoch 827/1000
# 474/474 - 1s - loss: 3.9773 - val_loss: 2.4306 - 982ms/epoch - 2ms/step
# Epoch 828/1000
# 474/474 - 1s - loss: 3.4290 - val_loss: 3.9395 - 1s/epoch - 2ms/step
# Epoch 829/1000
# 474/474 - 1s - loss: 3.1336 - val_loss: 2.8656 - 925ms/epoch - 2ms/step
# Epoch 830/1000
# 474/474 - 1s - loss: 3.4190 - val_loss: 3.4521 - 895ms/epoch - 2ms/step
# Epoch 831/1000
# 474/474 - 1s - loss: 3.6122 - val_loss: 4.5548 - 987ms/epoch - 2ms/step
# Epoch 832/1000
# 474/474 - 1s - loss: 3.5505 - val_loss: 4.4568 - 904ms/epoch - 2ms/step
# Epoch 833/1000
# 474/474 - 1s - loss: 3.5149 - val_loss: 4.2916 - 905ms/epoch - 2ms/step
# Epoch 834/1000
# 474/474 - 1s - loss: 3.7072 - val_loss: 2.4521 - 983ms/epoch - 2ms/step
# Epoch 835/1000
# 474/474 - 1s - loss: 3.2483 - val_loss: 3.0513 - 916ms/epoch - 2ms/step
# Epoch 836/1000
# 474/474 - 1s - loss: 3.3825 - val_loss: 2.5254 - 992ms/epoch - 2ms/step
# Epoch 837/1000
# 474/474 - 1s - loss: 3.1403 - val_loss: 2.7265 - 978ms/epoch - 2ms/step
# Epoch 838/1000
# 474/474 - 1s - loss: 3.3145 - val_loss: 2.5916 - 929ms/epoch - 2ms/step
# Epoch 839/1000
# 474/474 - 1s - loss: 3.1197 - val_loss: 2.4303 - 1s/epoch - 2ms/step
# Epoch 840/1000
# 474/474 - 1s - loss: 3.3635 - val_loss: 2.6723 - 934ms/epoch - 2ms/step
# Epoch 841/1000
# 474/474 - 1s - loss: 3.3488 - val_loss: 2.3623 - 903ms/epoch - 2ms/step
# Epoch 842/1000
# 474/474 - 1s - loss: 3.1973 - val_loss: 2.9109 - 1s/epoch - 2ms/step
# Epoch 843/1000
# 474/474 - 1s - loss: 3.4644 - val_loss: 2.3326 - 920ms/epoch - 2ms/step
# Epoch 844/1000
# 474/474 - 1s - loss: 3.1270 - val_loss: 3.1871 - 912ms/epoch - 2ms/step
# Epoch 845/1000
# 474/474 - 1s - loss: 3.6929 - val_loss: 2.5652 - 923ms/epoch - 2ms/step
# Epoch 846/1000
# 474/474 - 1s - loss: 3.2256 - val_loss: 2.7361 - 916ms/epoch - 2ms/step
# Epoch 847/1000
# 474/474 - 1s - loss: 3.0303 - val_loss: 2.5894 - 985ms/epoch - 2ms/step
# Epoch 848/1000
# 474/474 - 1s - loss: 3.6740 - val_loss: 3.0539 - 985ms/epoch - 2ms/step
# Epoch 849/1000
# 474/474 - 1s - loss: 3.4232 - val_loss: 6.8598 - 904ms/epoch - 2ms/step
# Epoch 850/1000
# 474/474 - 1s - loss: 3.5308 - val_loss: 5.3139 - 972ms/epoch - 2ms/step
# Epoch 851/1000
# 474/474 - 1s - loss: 3.1266 - val_loss: 3.6466 - 951ms/epoch - 2ms/step
# Epoch 852/1000
# 474/474 - 1s - loss: 3.2277 - val_loss: 2.9415 - 922ms/epoch - 2ms/step
# Epoch 853/1000
# 474/474 - 1s - loss: 3.3650 - val_loss: 7.1803 - 993ms/epoch - 2ms/step
# Epoch 854/1000
# 474/474 - 1s - loss: 3.5288 - val_loss: 4.3922 - 967ms/epoch - 2ms/step
# Epoch 855/1000
# 474/474 - 1s - loss: 3.6955 - val_loss: 3.0683 - 913ms/epoch - 2ms/step
# Epoch 856/1000
# 474/474 - 1s - loss: 3.1981 - val_loss: 3.5713 - 922ms/epoch - 2ms/step
# Epoch 857/1000
# 474/474 - 1s - loss: 3.2829 - val_loss: 2.3901 - 910ms/epoch - 2ms/step
# Epoch 858/1000
# 474/474 - 1s - loss: 3.4975 - val_loss: 2.7328 - 1s/epoch - 2ms/step
# Epoch 859/1000
# 474/474 - 1s - loss: 3.6441 - val_loss: 7.5178 - 952ms/epoch - 2ms/step
# Epoch 860/1000
# 474/474 - 1s - loss: 4.4085 - val_loss: 4.1985 - 1s/epoch - 2ms/step
# Epoch 861/1000
# 474/474 - 1s - loss: 3.3335 - val_loss: 2.8049 - 961ms/epoch - 2ms/step
# Epoch 862/1000
# 474/474 - 1s - loss: 3.1133 - val_loss: 2.3403 - 1s/epoch - 2ms/step
# Epoch 863/1000
# 474/474 - 1s - loss: 3.4312 - val_loss: 2.5849 - 919ms/epoch - 2ms/step
# Epoch 864/1000
# 474/474 - 1s - loss: 3.1023 - val_loss: 2.3415 - 983ms/epoch - 2ms/step
# Epoch 865/1000
# 474/474 - 1s - loss: 3.0373 - val_loss: 2.5362 - 934ms/epoch - 2ms/step
# Epoch 866/1000
# 474/474 - 1s - loss: 3.1715 - val_loss: 2.3468 - 924ms/epoch - 2ms/step
# Epoch 867/1000
# 474/474 - 1s - loss: 3.5711 - val_loss: 2.3541 - 918ms/epoch - 2ms/step
# Epoch 868/1000
# 474/474 - 1s - loss: 3.4792 - val_loss: 2.7717 - 916ms/epoch - 2ms/step
# Epoch 869/1000
# 474/474 - 1s - loss: 3.2750 - val_loss: 2.6142 - 941ms/epoch - 2ms/step
# Epoch 870/1000
# 474/474 - 1s - loss: 3.5204 - val_loss: 3.6133 - 898ms/epoch - 2ms/step
# Epoch 871/1000
# 474/474 - 1s - loss: 3.0547 - val_loss: 5.6989 - 1s/epoch - 2ms/step
# Epoch 872/1000
# 474/474 - 1s - loss: 2.9958 - val_loss: 2.5162 - 1s/epoch - 2ms/step
# Epoch 873/1000
# 474/474 - 1s - loss: 3.4861 - val_loss: 2.6087 - 911ms/epoch - 2ms/step
# Epoch 874/1000
# 474/474 - 1s - loss: 3.3908 - val_loss: 4.1995 - 907ms/epoch - 2ms/step
# Epoch 875/1000
# 474/474 - 1s - loss: 3.5777 - val_loss: 2.4974 - 905ms/epoch - 2ms/step
# Epoch 876/1000
# 474/474 - 1s - loss: 2.9129 - val_loss: 2.1821 - 996ms/epoch - 2ms/step
# Epoch 877/1000
# 474/474 - 1s - loss: 3.9615 - val_loss: 3.5600 - 922ms/epoch - 2ms/step
# Epoch 878/1000
# 474/474 - 1s - loss: 3.2340 - val_loss: 2.3418 - 940ms/epoch - 2ms/step
# Epoch 879/1000
# 474/474 - 1s - loss: 3.7664 - val_loss: 2.9384 - 986ms/epoch - 2ms/step
# Epoch 880/1000
# 474/474 - 1s - loss: 3.2964 - val_loss: 4.0421 - 922ms/epoch - 2ms/step
# Epoch 881/1000
# 474/474 - 1s - loss: 3.4111 - val_loss: 2.3136 - 971ms/epoch - 2ms/step
# Epoch 882/1000
# 474/474 - 1s - loss: 3.1810 - val_loss: 3.3826 - 966ms/epoch - 2ms/step
# Epoch 883/1000
# 474/474 - 1s - loss: 2.9917 - val_loss: 7.3338 - 925ms/epoch - 2ms/step
# Epoch 884/1000
# 474/474 - 1s - loss: 3.8356 - val_loss: 4.9169 - 897ms/epoch - 2ms/step
# Epoch 885/1000
# 474/474 - 1s - loss: 3.1106 - val_loss: 2.7088 - 929ms/epoch - 2ms/step
# Epoch 886/1000
# 474/474 - 1s - loss: 3.3542 - val_loss: 2.6051 - 986ms/epoch - 2ms/step
# Epoch 887/1000
# 474/474 - 1s - loss: 2.9569 - val_loss: 2.7112 - 1s/epoch - 2ms/step
# Epoch 888/1000
# 474/474 - 1s - loss: 3.2067 - val_loss: 2.8785 - 906ms/epoch - 2ms/step
# Epoch 889/1000
# 474/474 - 1s - loss: 3.5423 - val_loss: 3.2055 - 996ms/epoch - 2ms/step
# Epoch 890/1000
# 474/474 - 1s - loss: 3.3165 - val_loss: 2.6544 - 895ms/epoch - 2ms/step
# Epoch 891/1000
# 474/474 - 1s - loss: 3.8711 - val_loss: 2.5669 - 914ms/epoch - 2ms/step
# Epoch 892/1000
# 474/474 - 1s - loss: 2.9458 - val_loss: 2.9364 - 988ms/epoch - 2ms/step
# Epoch 893/1000
# 474/474 - 1s - loss: 3.1732 - val_loss: 2.6108 - 988ms/epoch - 2ms/step
# Epoch 894/1000
# 474/474 - 1s - loss: 3.3762 - val_loss: 2.4318 - 913ms/epoch - 2ms/step
# Epoch 895/1000
# 474/474 - 1s - loss: 3.3583 - val_loss: 3.6501 - 894ms/epoch - 2ms/step
# Epoch 896/1000
# 474/474 - 1s - loss: 2.9101 - val_loss: 2.5991 - 977ms/epoch - 2ms/step
# Epoch 897/1000
# 474/474 - 1s - loss: 2.9799 - val_loss: 2.9846 - 906ms/epoch - 2ms/step
# Epoch 898/1000
# 474/474 - 1s - loss: 3.3597 - val_loss: 4.0319 - 903ms/epoch - 2ms/step
# Epoch 899/1000
# 474/474 - 1s - loss: 3.7679 - val_loss: 3.6559 - 919ms/epoch - 2ms/step
# Epoch 900/1000
# 474/474 - 1s - loss: 2.9322 - val_loss: 4.1885 - 979ms/epoch - 2ms/step
# Epoch 901/1000
# 474/474 - 1s - loss: 3.2373 - val_loss: 3.0797 - 931ms/epoch - 2ms/step
# Epoch 902/1000
# 474/474 - 1s - loss: 3.0021 - val_loss: 3.7358 - 909ms/epoch - 2ms/step
# Epoch 903/1000
# 474/474 - 1s - loss: 2.7299 - val_loss: 3.0566 - 933ms/epoch - 2ms/step
# Epoch 904/1000
# 474/474 - 1s - loss: 3.2462 - val_loss: 3.2730 - 929ms/epoch - 2ms/step
# Epoch 905/1000
# 474/474 - 1s - loss: 3.1993 - val_loss: 3.5364 - 894ms/epoch - 2ms/step
# Epoch 906/1000
# 474/474 - 1s - loss: 3.2322 - val_loss: 2.6533 - 999ms/epoch - 2ms/step
# Epoch 907/1000
# 474/474 - 1s - loss: 2.8008 - val_loss: 2.5547 - 902ms/epoch - 2ms/step
# Epoch 908/1000
# 474/474 - 1s - loss: 3.5698 - val_loss: 2.4727 - 995ms/epoch - 2ms/step
# Epoch 909/1000
# 474/474 - 1s - loss: 3.3019 - val_loss: 12.7972 - 991ms/epoch - 2ms/step
# Epoch 910/1000
# 474/474 - 1s - loss: 3.1208 - val_loss: 3.1435 - 919ms/epoch - 2ms/step
# Epoch 911/1000
# 474/474 - 1s - loss: 2.8924 - val_loss: 2.4667 - 921ms/epoch - 2ms/step
# Epoch 912/1000
# 474/474 - 1s - loss: 3.3310 - val_loss: 2.9441 - 917ms/epoch - 2ms/step
# Epoch 913/1000
# 474/474 - 1s - loss: 3.0420 - val_loss: 2.4323 - 899ms/epoch - 2ms/step
# Epoch 914/1000
# 474/474 - 1s - loss: 3.3982 - val_loss: 3.3437 - 1s/epoch - 2ms/step
# Epoch 915/1000
# 474/474 - 1s - loss: 3.4361 - val_loss: 2.6282 - 907ms/epoch - 2ms/step
# Epoch 916/1000
# 474/474 - 1s - loss: 2.9665 - val_loss: 2.5054 - 986ms/epoch - 2ms/step
# Epoch 917/1000
# 474/474 - 1s - loss: 3.3104 - val_loss: 3.7233 - 918ms/epoch - 2ms/step
# Epoch 918/1000
# 474/474 - 1s - loss: 3.5915 - val_loss: 5.6890 - 893ms/epoch - 2ms/step
# Epoch 919/1000
# 474/474 - 1s - loss: 3.2889 - val_loss: 3.6892 - 929ms/epoch - 2ms/step
# Epoch 920/1000
# 474/474 - 1s - loss: 3.3773 - val_loss: 2.5819 - 993ms/epoch - 2ms/step
# Epoch 921/1000
# 474/474 - 1s - loss: 2.8124 - val_loss: 4.1060 - 897ms/epoch - 2ms/step
# Epoch 922/1000
# 474/474 - 1s - loss: 3.4026 - val_loss: 5.7767 - 1s/epoch - 2ms/step
# Epoch 923/1000
# 474/474 - 1s - loss: 3.2608 - val_loss: 3.3577 - 933ms/epoch - 2ms/step
# Epoch 924/1000
# 474/474 - 1s - loss: 2.9912 - val_loss: 3.5003 - 1s/epoch - 2ms/step
# Epoch 925/1000
# 474/474 - 1s - loss: 2.9228 - val_loss: 3.6097 - 1s/epoch - 2ms/step
# Epoch 926/1000
# 474/474 - 1s - loss: 3.2920 - val_loss: 2.1266 - 972ms/epoch - 2ms/step
# Epoch 927/1000
# 474/474 - 1s - loss: 3.1736 - val_loss: 2.4465 - 994ms/epoch - 2ms/step
# Epoch 928/1000
# 474/474 - 1s - loss: 2.7556 - val_loss: 2.6476 - 974ms/epoch - 2ms/step
# Epoch 929/1000
# 474/474 - 1s - loss: 3.6460 - val_loss: 2.5372 - 988ms/epoch - 2ms/step
# Epoch 930/1000
# 474/474 - 1s - loss: 3.5393 - val_loss: 3.8880 - 915ms/epoch - 2ms/step
# Epoch 931/1000
# 474/474 - 1s - loss: 3.6766 - val_loss: 2.2948 - 903ms/epoch - 2ms/step
# Epoch 932/1000
# 474/474 - 1s - loss: 3.2486 - val_loss: 2.9326 - 914ms/epoch - 2ms/step
# Epoch 933/1000
# 474/474 - 1s - loss: 3.0980 - val_loss: 2.8709 - 988ms/epoch - 2ms/step
# Epoch 934/1000
# 474/474 - 1s - loss: 2.9860 - val_loss: 3.1547 - 917ms/epoch - 2ms/step
# Epoch 935/1000
# 474/474 - 1s - loss: 2.8810 - val_loss: 6.4666 - 925ms/epoch - 2ms/step
# Epoch 936/1000
# 474/474 - 1s - loss: 3.5668 - val_loss: 8.8043 - 999ms/epoch - 2ms/step
# Epoch 937/1000
# 474/474 - 1s - loss: 3.0659 - val_loss: 2.8709 - 1s/epoch - 2ms/step
# Epoch 938/1000
# 474/474 - 1s - loss: 3.4392 - val_loss: 3.6161 - 901ms/epoch - 2ms/step
# Epoch 939/1000
# 474/474 - 1s - loss: 3.3476 - val_loss: 2.2236 - 992ms/epoch - 2ms/step
# Epoch 940/1000
# 474/474 - 1s - loss: 3.0022 - val_loss: 2.2651 - 947ms/epoch - 2ms/step
# Epoch 941/1000
# 474/474 - 1s - loss: 3.1317 - val_loss: 3.9482 - 913ms/epoch - 2ms/step
# Epoch 942/1000
# 474/474 - 1s - loss: 3.6268 - val_loss: 3.0974 - 984ms/epoch - 2ms/step
# Epoch 943/1000
# 474/474 - 1s - loss: 3.1793 - val_loss: 4.8873 - 934ms/epoch - 2ms/step
# Epoch 944/1000
# 474/474 - 1s - loss: 3.2081 - val_loss: 2.1754 - 934ms/epoch - 2ms/step
# Epoch 945/1000
# 474/474 - 1s - loss: 3.2261 - val_loss: 6.0338 - 893ms/epoch - 2ms/step
# Epoch 946/1000
# 474/474 - 1s - loss: 3.8954 - val_loss: 2.9568 - 903ms/epoch - 2ms/step
# Epoch 947/1000
# 474/474 - 1s - loss: 3.0475 - val_loss: 2.8293 - 981ms/epoch - 2ms/step
# Epoch 948/1000
# 474/474 - 1s - loss: 2.9116 - val_loss: 3.4485 - 945ms/epoch - 2ms/step
# Epoch 949/1000
# 474/474 - 1s - loss: 3.1074 - val_loss: 2.4939 - 906ms/epoch - 2ms/step
# Epoch 950/1000
# 474/474 - 1s - loss: 3.0409 - val_loss: 2.8915 - 981ms/epoch - 2ms/step
# Epoch 951/1000
# 474/474 - 1s - loss: 3.2339 - val_loss: 3.9582 - 911ms/epoch - 2ms/step
# Epoch 952/1000
# 474/474 - 1s - loss: 3.2946 - val_loss: 5.9025 - 983ms/epoch - 2ms/step
# Epoch 953/1000
# 474/474 - 1s - loss: 3.3216 - val_loss: 2.9307 - 957ms/epoch - 2ms/step
# Epoch 954/1000
# 474/474 - 1s - loss: 3.2078 - val_loss: 2.3149 - 935ms/epoch - 2ms/step
# Epoch 955/1000
# 474/474 - 1s - loss: 2.8223 - val_loss: 3.9469 - 920ms/epoch - 2ms/step
# Epoch 956/1000
# 474/474 - 1s - loss: 3.4255 - val_loss: 2.7340 - 903ms/epoch - 2ms/step
# Epoch 957/1000
# 474/474 - 1s - loss: 3.2990 - val_loss: 3.4148 - 926ms/epoch - 2ms/step
# Epoch 958/1000
# 474/474 - 1s - loss: 3.5641 - val_loss: 2.3674 - 907ms/epoch - 2ms/step
# Epoch 959/1000
# 474/474 - 1s - loss: 3.4049 - val_loss: 3.2991 - 969ms/epoch - 2ms/step
# Epoch 960/1000
# 474/474 - 1s - loss: 3.6834 - val_loss: 2.3434 - 896ms/epoch - 2ms/step
# Epoch 961/1000
# 474/474 - 1s - loss: 3.2726 - val_loss: 3.2471 - 940ms/epoch - 2ms/step
# Epoch 962/1000
# 474/474 - 1s - loss: 3.4289 - val_loss: 2.6078 - 891ms/epoch - 2ms/step
# Epoch 963/1000
# 474/474 - 1s - loss: 2.9094 - val_loss: 7.8144 - 924ms/epoch - 2ms/step
# Epoch 964/1000
# 474/474 - 1s - loss: 3.4495 - val_loss: 3.8003 - 917ms/epoch - 2ms/step
# Epoch 965/1000
# 474/474 - 1s - loss: 2.9608 - val_loss: 2.9731 - 935ms/epoch - 2ms/step
# Epoch 966/1000
# 474/474 - 1s - loss: 3.1903 - val_loss: 2.0862 - 1s/epoch - 2ms/step
# Epoch 967/1000
# 474/474 - 1s - loss: 3.1631 - val_loss: 2.1292 - 917ms/epoch - 2ms/step
# Epoch 968/1000
# 474/474 - 1s - loss: 3.8893 - val_loss: 2.5650 - 983ms/epoch - 2ms/step
# Epoch 969/1000
# 474/474 - 1s - loss: 2.9025 - val_loss: 2.3648 - 989ms/epoch - 2ms/step
# Epoch 970/1000
# 474/474 - 1s - loss: 3.6179 - val_loss: 2.6476 - 922ms/epoch - 2ms/step
# Epoch 971/1000
# 474/474 - 1s - loss: 3.2197 - val_loss: 2.8774 - 899ms/epoch - 2ms/step
# Epoch 972/1000
# 474/474 - 1s - loss: 2.8371 - val_loss: 2.5209 - 979ms/epoch - 2ms/step
# Epoch 973/1000
# 474/474 - 1s - loss: 3.0881 - val_loss: 3.0892 - 912ms/epoch - 2ms/step
# Epoch 974/1000
# 474/474 - 1s - loss: 3.0887 - val_loss: 2.2926 - 933ms/epoch - 2ms/step
# Epoch 975/1000
# 474/474 - 1s - loss: 3.0910 - val_loss: 3.3708 - 905ms/epoch - 2ms/step
# Epoch 976/1000
# 474/474 - 1s - loss: 3.3105 - val_loss: 2.8963 - 922ms/epoch - 2ms/step
# Epoch 977/1000
# 474/474 - 1s - loss: 2.8274 - val_loss: 2.1206 - 912ms/epoch - 2ms/step
# Epoch 978/1000
# 474/474 - 1s - loss: 2.8446 - val_loss: 2.4032 - 1s/epoch - 2ms/step
# Epoch 979/1000
# 474/474 - 1s - loss: 2.8208 - val_loss: 2.1714 - 989ms/epoch - 2ms/step
# Epoch 980/1000
# 474/474 - 1s - loss: 2.8481 - val_loss: 2.4359 - 896ms/epoch - 2ms/step
# Epoch 981/1000
# 474/474 - 1s - loss: 3.3345 - val_loss: 2.6565 - 1s/epoch - 2ms/step
# Epoch 982/1000
# 474/474 - 1s - loss: 3.0016 - val_loss: 2.3956 - 897ms/epoch - 2ms/step
# Epoch 983/1000
# 474/474 - 1s - loss: 3.2334 - val_loss: 3.2762 - 993ms/epoch - 2ms/step
# Epoch 984/1000
# 474/474 - 1s - loss: 3.1298 - val_loss: 3.2359 - 987ms/epoch - 2ms/step
# Epoch 985/1000
# 474/474 - 1s - loss: 3.0665 - val_loss: 2.7531 - 922ms/epoch - 2ms/step
# Epoch 986/1000
# 474/474 - 1s - loss: 3.0728 - val_loss: 2.7080 - 923ms/epoch - 2ms/step
# Epoch 987/1000
# 474/474 - 1s - loss: 3.3427 - val_loss: 2.8853 - 1s/epoch - 2ms/step
# Epoch 988/1000
# 474/474 - 1s - loss: 3.2060 - val_loss: 2.6860 - 978ms/epoch - 2ms/step
# Epoch 989/1000
# 474/474 - 1s - loss: 3.0130 - val_loss: 2.1395 - 1s/epoch - 2ms/step
# Epoch 990/1000
# 474/474 - 1s - loss: 2.7249 - val_loss: 2.7480 - 893ms/epoch - 2ms/step
# Epoch 991/1000
# 474/474 - 1s - loss: 3.5908 - val_loss: 4.3663 - 908ms/epoch - 2ms/step
# Epoch 992/1000
# 474/474 - 1s - loss: 2.7146 - val_loss: 2.3968 - 995ms/epoch - 2ms/step
# Epoch 993/1000
# 474/474 - 1s - loss: 3.2014 - val_loss: 11.3500 - 902ms/epoch - 2ms/step
# Epoch 994/1000
# 474/474 - 1s - loss: 3.4438 - val_loss: 2.5141 - 980ms/epoch - 2ms/step
# Epoch 995/1000
# 474/474 - 1s - loss: 2.9018 - val_loss: 4.4337 - 1s/epoch - 2ms/step
# Epoch 996/1000
# 474/474 - 1s - loss: 3.2059 - val_loss: 4.9949 - 975ms/epoch - 2ms/step
# Epoch 997/1000
# 474/474 - 1s - loss: 2.9681 - val_loss: 2.1584 - 904ms/epoch - 2ms/step
# Epoch 998/1000
# 474/474 - 1s - loss: 3.1811 - val_loss: 7.5086 - 1s/epoch - 2ms/step
# Epoch 999/1000
# 474/474 - 1s - loss: 2.9881 - val_loss: 2.8762 - 910ms/epoch - 2ms/step
# Epoch 1000/1000
# 474/474 - 1s - loss: 3.3377 - val_loss: 2.1065 - 984ms/epoch - 2ms/step

# %%
# Plot training history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
plt.title('Training Vs Validation loss')
pyplot.legend()
pyplot.show()

# %%
# Plot actual vs prediction for training set
TestResults = numpy.genfromtxt("trainresults.csv", delimiter=",")
plt.plot(y_train,TestResults,'ro')
plt.title('Training Set')
plt.xlabel('Actual SOH')
plt.ylabel('Predicted SOH')

# Compute R-Square value for training set
TestR2Value = r2_score(y_train,TestResults)
print("Training Set R-Square =", TestR2Value)
TestMSEValue = mean_squared_error(y_train,TestResults)
print("Training Set Mean Squared Error =", TestMSEValue)
# Out:
# Training Set R-Square = 0.9678759319273471
# Training Set Mean Squared Error = 2.181368389266433

# %%
# Plot actual vs prediction for validation set
ValResults = numpy.genfromtxt("valresults.csv", delimiter=",")
plt.plot(y_valid,ValResults,'ro')
plt.title('Validation Set')
plt.xlabel('Actual SOH')
plt.ylabel('Predicted SOH')

# Compute R-Square value for validation set
ValR2Value = r2_score(y_valid,ValResults)
print("Validation Set R-Square=",ValR2Value)
ValMSEValue = mean_squared_error(y_valid,ValResults)
print("Validation Set MSE=",ValMSEValue)
# Out:
# Validation Set R-Square= 0.9702709947110729
# Validation Set MSE= 2.106511293640753

# %%
PredTestSet = model.predict(X_test)
# Save predictions
numpy.savetxt("testresults.csv", PredTestSet, delimiter=",")
Results = numpy.genfromtxt("testresults.csv", delimiter=",")
plt.plot(y_test,Results,'ro')
plt.title('Test Set')
plt.xlabel('Actual SOH')
plt.ylabel('Predicted SOH')

# Compute R-Square value for validation set
ValR2Value = r2_score(y_test,Results)
print("Test Set R-Square=",ValR2Value)
ValMSEValue = mean_squared_error(y_test,Results)
print("Test Set MSE=",ValMSEValue)
# Out:
# Test Set R-Square= 0.9701888307942597
# Test Set MSE= 1.8479673410207782

# %%
pd.read_csv('testresults.csv')
# Out:
#       9.424315643310546875e+01
# 0                    98.263626
# 1                    94.040642
# 2                    92.683807
# 3                    93.998878
# 4                    92.683098
# ...                        ...
# 5913                 94.084671
# 5914                 81.648117
# 5915                 98.334702
# 5916                 98.457283
# 5917                 84.245239
#
# [5918 rows x 1 columns]

# %% [markdown]
# So, as we see we have achieved a Regression Model using Feedforward Neural Network with 6 Hidden layers and Current, Number of Charge/Discharge cycles and Battery temperature to predict the State of Health(SOH).
#
#
# <mark>Test Set Model R2- value:- **0.97**
# </br>
# Mean Squared Error Loss for the Model on Test Dataset:- **1.84**
#
#
#
#
#
# For a new battery being used for the first time, the Remaining Useful life is usually calculated in terms of the charge/discharge cycles between 80-70 % SOH.
#
# So, Let's plot the predicted SOH against the cycles from test dataset to find the RUL of the battery.

# %%
plt.locator_params(axis="x", nbins=20)
plt.locator_params(axis="y", nbins=10)
plt.plot(X_test['cycles'],Results,'go')
plt.plot(X_test['cycles'][Results<80],Results[Results<80],'ro')
plt.title('SOH Vs Cycles')
plt.xlabel('Cycles')
plt.ylabel(' Predicted SOH')
plt.grid()
plt.show()

# %% [markdown]
# **<mark>So, as we see that the approximate RUL of the battery at a Standard Temperature of 25 degree is predicted to be around 550 Cycles where the SOH drops to 80% ( as shown in red curve)**
